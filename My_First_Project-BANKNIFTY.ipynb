# %%
import numpy as np
import pandas as pd
import pickle

import matplotlib.pylab as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor 
from sklearn.ensemble import VotingRegressor

from pandas_datareader import data
import math
import pandas_datareader as web
import datetime as dt
import urllib.request, json
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Loading the dataset
data_source = 'yahoo'
symbol='^NSEBANK'
def load_data(data_source,symbol):
    if data_source=='alphavantage':
        api_key="SP3HAWW995G61TIL"
        url_string = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=%s&outputsize=full&apikey=%s"%(symbol,api_key)
        file_to_save='stock_market_data-%s.csv'%symbol

        if not os.path.exists(file_to_save):
            with urllib.request.urlopen(url_string) as url:
                data=json.loads(url.read().decode())
                data=data['Time Series (Daily)']
                ds=pd.dataframe(columns=['Date','Low','High','Close','Open'])
                for k,v in data.items():
                    date=dt.datetime.strptime(k,'%Y-%m-%d')
                    data_row=[date.date(),float(v['3. low']),float(v['2. high']),float(v['4. close']),float(v['1. open'])]
                    ds.loc[-1,:]=data_row
                    ds.index=ds.index+1
                print('Data saved to %s'%file_to_save)
                ds.to_csv(file_to_save)
        else:
            print('File already exists. Loading data from csv')
            ds=pd.read_csv(file_to_save)

    elif data_source=='kaggle':
        ds=pd.read_csv(os.path.join('Stocks','hpq.us.txt'),delimiter=',',usecols=['Date','Open','High','Low','Close'])
        print('Loaded data from kaggle repository')

    else:
        #ds = web.DataReader(symbol, data_source='yahoo', start='2007-01-01', end='2020-12-24')
        ds = web.get_data_yahoo('^NSEBANK','01/01/2010',interval='w')
    return ds

ds=load_data(data_source,symbol)
ds=ds.sort_values('Date')
ds.tail()
# Out:
#                     High           Low          Open         Close    Volume  \
# Date
# 2020-12-10  30945.199219  30328.449219  30555.300781  30847.050781  548400.0
# 2020-12-17  30854.050781  28976.750000  30841.849609  30402.199219       0.0
# 2020-12-24  31510.250000  30538.150391  30558.849609  31264.050781       0.0
# 2020-12-31  31982.300781  30893.650391  31485.150391  31797.900391       0.0
# 2021-01-07  32147.800781  31950.900391  32129.800781  32123.000000       0.0
#
#                Adj Close
# Date
# 2020-12-10  30847.050781
# 2020-12-17  30402.199219
# 2020-12-24  31264.050781
# 2020-12-31  31797.900391
# 2021-01-07  32123.000000

# %%
print("\nSample Data")
print("===========\n")
print(ds.head())
print(ds.shape)
# Out:
# Sample Data
# ===========
#
#                    High          Low         Open        Close  Volume  \
# Date
# 2009-12-31  5310.850098  5167.100098  5200.899902  5263.100098       0
# 2010-01-07  5300.500000  5169.549805  5264.250000  5259.899902       0
# 2010-01-14  5292.500000  5085.450195  5259.899902  5094.149902       0
# 2010-01-21  5094.149902  4824.950195  5094.149902  4867.250000       0
# 2010-01-28  4951.149902  4766.000000  4866.149902  4845.350098       0
#
#               Adj Close
# Date
# 2009-12-31  5263.100098
# 2010-01-07  5259.899902
# 2010-01-14  5094.149902
# 2010-01-21  4867.250000
# 2010-01-28  4845.350098
# (576, 6)

# %%
print("\n\nAttributes in Sample Data:")
print("==========================\n")

print(ds.columns)

print("\n\nNumber of Instances in Sample Data:")
print("========================================\n")
print(ds.iloc[: ,].count())
# Out:
# Attributes in Sample Data:
# ==========================
#
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')
#
#
# Number of Instances in Sample Data:
# ========================================
#
# High         576
# Low          576
# Open         576
# Close        576
# Volume       576
# Adj Close    576
# dtype: int64

# %%
# Dividing the dataset into input and otput

X = ds.drop("Close", axis = 1)
y = ds["Close"]

print(X.columns)
# Out:
# Index(['High', 'Low', 'Open', 'Volume', 'Adj Close'], dtype='object')

# %%
# Checking the datatypes of input and fetures

print(X.dtypes)
print(y.dtypes)
# Out:
# High         float64
# Low          float64
# Open         float64
# Volume         int64
# Adj Close    float64
# dtype: object
# float64

# %%
# Checking the correlation between various parameters

print(ds[["Open", "Close"]].corr(),"\n")
print(ds[["High", "Close"]].corr(),"\n")
print(ds[["Low", "Close"]].corr(),"\n")
print(ds[["Volume", "Close"]].corr())
# Out:
#            Open     Close
# Open   1.000000  0.996916
# Close  0.996916  1.000000
#
#            High     Close
# High   1.000000  0.998279
# Close  0.998279  1.000000
#
#             Low     Close
# Low    1.000000  0.998474
# Close  0.998474  1.000000
#
#           Volume     Close
# Volume  1.000000  0.737449
# Close   0.737449  1.000000

# %%
# Splitting of input and output data into Train and Test

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 0 , shuffle = False)

# %%
# Training our dataset using LinearRegression as model

model_LR = LinearRegression().fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_LR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_LR.score(x_test, y_test))

pickle.dump(model_LR, open ('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_LR.pkl','wb'))
# Out:
# Score on training data:
# ========================================
# 1.00000
#
#
# Score on testing data:
# ========================================
# 1.00000

# %%
y_pred_LR = model_LR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_LR)):
    expl=((actual_data[i]-y_pred_LR[i])/actual_data[i])*100.0
    print('Actual Value {:,.2f}, Predicted value {:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_LR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value 8,673.25, Predicted value 8,673.25 (%0.00)
# Actual Value 8,592.20, Predicted value 8,592.20 (%0.00)
# Actual Value 8,774.65, Predicted value 8,774.65 (%0.00)
# Actual Value 8,952.50, Predicted value 8,952.50 (%0.00)
# Actual Value 8,742.55, Predicted value 8,742.55 (%0.00)
# Actual Value 8,867.45, Predicted value 8,867.45 (%0.00)
# Actual Value 8,591.25, Predicted value 8,591.25 (%0.00)
# Actual Value 8,709.55, Predicted value 8,709.55 (%0.00)
# Actual Value 8,573.35, Predicted value 8,573.35 (%0.00)
# Actual Value 8,699.40, Predicted value 8,699.40 (%0.00)
# Actual Value 8,615.25, Predicted value 8,615.25 (%0.00)
# Actual Value 8,484.95, Predicted value 8,484.95 (%0.00)
# Actual Value 8,525.75, Predicted value 8,525.75 (%0.00)
# Actual Value 8,079.95, Predicted value 8,079.95 (%0.00)
# Actual Value 7,965.50, Predicted value 7,965.50 (%0.00)
# Actual Value 8,192.90, Predicted value 8,192.90 (%0.00)
# Actual Value 8,246.85, Predicted value 8,246.85 (%0.00)
# Actual Value 8,153.60, Predicted value 8,153.60 (%0.00)
# Actual Value 7,979.10, Predicted value 7,979.10 (%0.00)
# Actual Value 8,103.60, Predicted value 8,103.60 (%0.00)
# Actual Value 8,273.80, Predicted value 8,273.80 (%0.00)
# Actual Value 8,407.20, Predicted value 8,407.20 (%0.00)
# Actual Value 8,435.10, Predicted value 8,435.10 (%0.00)
# Actual Value 8,602.75, Predicted value 8,602.75 (%0.00)
# Actual Value 8,734.25, Predicted value 8,734.25 (%0.00)
# Actual Value 8,778.40, Predicted value 8,778.40 (%0.00)
# Actual Value 8,778.00, Predicted value 8,778.00 (%0.00)
# Actual Value 8,939.50, Predicted value 8,939.50 (%0.00)
# Actual Value 8,899.75, Predicted value 8,899.75 (%0.00)
# Actual Value 8,927.00, Predicted value 8,927.00 (%0.00)
# Actual Value 9,153.70, Predicted value 9,153.70 (%0.00)
# Actual Value 9,086.30, Predicted value 9,086.30 (%0.00)
# Actual Value 9,173.75, Predicted value 9,173.75 (%0.00)
# Actual Value 9,261.95, Predicted value 9,261.95 (%0.00)
# Actual Value 9,150.80, Predicted value 9,150.80 (%0.00)
# Actual Value 9,136.40, Predicted value 9,136.40 (%0.00)
# Actual Value 9,342.15, Predicted value 9,342.15 (%0.00)
# Actual Value 9,359.90, Predicted value 9,359.90 (%0.00)
# Actual Value 9,422.40, Predicted value 9,422.40 (%0.00)
# Actual Value 9,429.45, Predicted value 9,429.45 (%0.00)
# Actual Value 9,509.75, Predicted value 9,509.75 (%0.00)
# Actual Value 9,616.10, Predicted value 9,616.10 (%0.00)
# Actual Value 9,647.25, Predicted value 9,647.25 (%0.00)
# Actual Value 9,578.05, Predicted value 9,578.05 (%0.00)
# Actual Value 9,630.00, Predicted value 9,630.00 (%0.00)
# Actual Value 9,504.10, Predicted value 9,504.10 (%0.00)
# Actual Value 9,674.55, Predicted value 9,674.55 (%0.00)
# Actual Value 9,891.70, Predicted value 9,891.70 (%0.00)
# Actual Value 9,873.30, Predicted value 9,873.30 (%0.00)
# Actual Value 10,020.55, Predicted value 10,020.55 (%0.00)
# Actual Value 10,013.65, Predicted value 10,013.65 (%0.00)
# Actual Value 9,820.25, Predicted value 9,820.25 (%0.00)
# Actual Value 9,904.15, Predicted value 9,904.15 (%0.00)
# Actual Value 9,857.05, Predicted value 9,857.05 (%0.00)
# Actual Value 9,917.90, Predicted value 9,917.90 (%0.00)
# Actual Value 9,929.90, Predicted value 9,929.90 (%0.00)
# Actual Value 10,086.60, Predicted value 10,086.60 (%0.00)
# Actual Value 10,121.90, Predicted value 10,121.90 (%0.00)
# Actual Value 9,768.95, Predicted value 9,768.95 (%0.00)
# Actual Value 9,888.70, Predicted value 9,888.70 (%0.00)
# Actual Value 10,096.40, Predicted value 10,096.40 (%0.00)
# Actual Value 10,146.55, Predicted value 10,146.55 (%0.00)
# Actual Value 10,343.80, Predicted value 10,343.80 (%0.00)
# Actual Value 10,423.80, Predicted value 10,423.80 (%0.00)
# Actual Value 10,308.95, Predicted value 10,308.95 (%0.00)
# Actual Value 10,214.75, Predicted value 10,214.75 (%0.00)
# Actual Value 10,348.75, Predicted value 10,348.75 (%0.00)
# Actual Value 10,226.55, Predicted value 10,226.55 (%0.00)
# Actual Value 10,166.70, Predicted value 10,166.70 (%0.00)
# Actual Value 10,252.10, Predicted value 10,252.10 (%0.00)
# Actual Value 10,440.30, Predicted value 10,440.30 (%0.00)
# Actual Value 10,477.90, Predicted value 10,477.90 (%0.00)
# Actual Value 10,504.80, Predicted value 10,504.80 (%0.00)
# Actual Value 10,651.20, Predicted value 10,651.20 (%0.00)
# Actual Value 10,817.00, Predicted value 10,817.00 (%0.00)
# Actual Value 11,069.65, Predicted value 11,069.65 (%0.00)
# Actual Value 11,016.90, Predicted value 11,016.90 (%0.00)
# Actual Value 10,576.85, Predicted value 10,576.85 (%0.00)
# Actual Value 10,545.50, Predicted value 10,545.50 (%0.00)
# Actual Value 10,382.70, Predicted value 10,382.70 (%0.00)
# Actual Value 10,458.35, Predicted value 10,458.35 (%0.00)
# Actual Value 10,242.65, Predicted value 10,242.65 (%0.00)
# Actual Value 10,360.15, Predicted value 10,360.15 (%0.00)
# Actual Value 10,114.75, Predicted value 10,114.75 (%0.00)
# Actual Value 10,113.70, Predicted value 10,113.70 (%0.00)
# Actual Value 10,325.15, Predicted value 10,325.15 (%0.00)
# Actual Value 10,458.65, Predicted value 10,458.65 (%0.00)
# Actual Value 10,565.30, Predicted value 10,565.30 (%0.00)
# Actual Value 10,617.80, Predicted value 10,617.80 (%0.00)
# Actual Value 10,679.65, Predicted value 10,679.65 (%0.00)
# Actual Value 10,716.55, Predicted value 10,716.55 (%0.00)
# Actual Value 10,682.70, Predicted value 10,682.70 (%0.00)
# Actual Value 10,513.85, Predicted value 10,513.85 (%0.00)
# Actual Value 10,736.15, Predicted value 10,736.15 (%0.00)
# Actual Value 10,768.35, Predicted value 10,768.35 (%0.00)
# Actual Value 10,808.05, Predicted value 10,808.05 (%0.00)
# Actual Value 10,741.10, Predicted value 10,741.10 (%0.00)
# Actual Value 10,589.10, Predicted value 10,589.10 (%0.00)
# Actual Value 10,749.75, Predicted value 10,749.75 (%0.00)
# Actual Value 11,023.20, Predicted value 11,023.20 (%0.00)
# Actual Value 10,957.10, Predicted value 10,957.10 (%0.00)
# Actual Value 11,167.30, Predicted value 11,167.30 (%0.00)
# Actual Value 11,244.70, Predicted value 11,244.70 (%0.00)
# Actual Value 11,470.70, Predicted value 11,470.70 (%0.00)
# Actual Value 11,385.05, Predicted value 11,385.05 (%0.00)
# Actual Value 11,582.75, Predicted value 11,582.75 (%0.00)
# Actual Value 11,676.80, Predicted value 11,676.80 (%0.00)
# Actual Value 11,536.90, Predicted value 11,536.90 (%0.00)
# Actual Value 11,369.90, Predicted value 11,369.90 (%0.00)
# Actual Value 11,234.35, Predicted value 11,234.35 (%0.00)
# Actual Value 10,977.55, Predicted value 10,977.55 (%0.00)
# Actual Value 10,599.25, Predicted value 10,599.25 (%0.00)
# Actual Value 10,234.65, Predicted value 10,234.65 (%0.00)
# Actual Value 10,453.05, Predicted value 10,453.05 (%0.00)
# Actual Value 10,124.90, Predicted value 10,124.90 (%0.00)
# Actual Value 10,380.45, Predicted value 10,380.45 (%0.00)
# Actual Value 10,598.40, Predicted value 10,598.40 (%0.00)
# Actual Value 10,616.70, Predicted value 10,616.70 (%0.00)
# Actual Value 10,526.75, Predicted value 10,526.75 (%0.00)
# Actual Value 10,858.70, Predicted value 10,858.70 (%0.00)
# Actual Value 10,601.15, Predicted value 10,601.15 (%0.00)
# Actual Value 10,791.55, Predicted value 10,791.55 (%0.00)
# Actual Value 10,951.70, Predicted value 10,951.70 (%0.00)
# Actual Value 10,779.80, Predicted value 10,779.80 (%0.00)
# Actual Value 10,672.25, Predicted value 10,672.25 (%0.00)
# Actual Value 10,821.60, Predicted value 10,821.60 (%0.00)
# Actual Value 10,905.20, Predicted value 10,905.20 (%0.00)
# Actual Value 10,849.80, Predicted value 10,849.80 (%0.00)
# Actual Value 10,830.95, Predicted value 10,830.95 (%0.00)
# Actual Value 11,069.40, Predicted value 11,069.40 (%0.00)
# Actual Value 10,746.05, Predicted value 10,746.05 (%0.00)
# Actual Value 10,789.85, Predicted value 10,789.85 (%0.00)
# Actual Value 10,792.50, Predicted value 10,792.50 (%0.00)
# Actual Value 11,058.20, Predicted value 11,058.20 (%0.00)
# Actual Value 11,343.25, Predicted value 11,343.25 (%0.00)
# Actual Value 11,521.05, Predicted value 11,521.05 (%0.00)
# Actual Value 11,570.00, Predicted value 11,570.00 (%0.00)
# Actual Value 11,598.00, Predicted value 11,598.00 (%0.00)
# Actual Value 11,596.70, Predicted value 11,596.70 (%0.00)
# Actual Value 11,752.80, Predicted value 11,752.80 (%0.00)
# Actual Value 11,641.80, Predicted value 11,641.80 (%0.00)
# Actual Value 11,724.75, Predicted value 11,724.75 (%0.00)
# Actual Value 11,301.80, Predicted value 11,301.80 (%0.00)
# Actual Value 11,257.10, Predicted value 11,257.10 (%0.00)
# Actual Value 11,657.05, Predicted value 11,657.05 (%0.00)
# Actual Value 11,945.90, Predicted value 11,945.90 (%0.00)
# Actual Value 11,843.75, Predicted value 11,843.75 (%0.00)
# Actual Value 11,914.05, Predicted value 11,914.05 (%0.00)
# Actual Value 11,831.75, Predicted value 11,831.75 (%0.00)
# Actual Value 11,841.55, Predicted value 11,841.55 (%0.00)
# Actual Value 11,946.75, Predicted value 11,946.75 (%0.00)
# Actual Value 11,582.90, Predicted value 11,582.90 (%0.00)
# Actual Value 11,596.90, Predicted value 11,596.90 (%0.00)
# Actual Value 11,252.15, Predicted value 11,252.15 (%0.00)
# Actual Value 10,980.00, Predicted value 10,980.00 (%0.00)
# Actual Value 11,032.45, Predicted value 11,032.45 (%0.00)
# Actual Value 11,029.40, Predicted value 11,029.40 (%0.00)
# Actual Value 10,741.35, Predicted value 10,741.35 (%0.00)
# Actual Value 10,948.30, Predicted value 10,948.30 (%0.00)
# Actual Value 10,847.90, Predicted value 10,847.90 (%0.00)
# Actual Value 10,982.80, Predicted value 10,982.80 (%0.00)
# Actual Value 10,704.80, Predicted value 10,704.80 (%0.00)
# Actual Value 11,571.20, Predicted value 11,571.20 (%0.00)
# Actual Value 11,314.00, Predicted value 11,314.00 (%0.00)
# Actual Value 11,234.55, Predicted value 11,234.55 (%0.00)
# Actual Value 11,586.35, Predicted value 11,586.35 (%0.00)
# Actual Value 11,582.60, Predicted value 11,582.60 (%0.00)
# Actual Value 11,877.45, Predicted value 11,877.45 (%0.00)
# Actual Value 12,012.05, Predicted value 12,012.05 (%0.00)
# Actual Value 11,872.10, Predicted value 11,872.10 (%0.00)
# Actual Value 11,968.40, Predicted value 11,968.40 (%0.00)
# Actual Value 12,151.15, Predicted value 12,151.15 (%0.00)
# Actual Value 12,018.40, Predicted value 12,018.40 (%0.00)
# Actual Value 11,971.80, Predicted value 11,971.80 (%0.00)
# Actual Value 12,259.70, Predicted value 12,259.70 (%0.00)
# Actual Value 12,126.55, Predicted value 12,126.55 (%0.00)
# Actual Value 12,282.20, Predicted value 12,282.20 (%0.00)
# Actual Value 12,215.90, Predicted value 12,215.90 (%0.00)
# Actual Value 12,355.50, Predicted value 12,355.50 (%0.00)
# Actual Value 12,180.35, Predicted value 12,180.35 (%0.00)
# Actual Value 12,035.80, Predicted value 12,035.80 (%0.00)
# Actual Value 12,137.95, Predicted value 12,137.95 (%0.00)
# Actual Value 12,174.65, Predicted value 12,174.65 (%0.00)
# Actual Value 12,080.85, Predicted value 12,080.85 (%0.00)
# Actual Value 11,633.30, Predicted value 11,633.30 (%0.00)
# Actual Value 11,269.00, Predicted value 11,269.00 (%0.00)
# Actual Value 9,590.15, Predicted value 9,590.15 (%0.00)
# Actual Value 8,263.45, Predicted value 8,263.45 (%0.00)
# Actual Value 8,641.45, Predicted value 8,641.45 (%0.00)
# Actual Value 8,253.80, Predicted value 8,253.80 (%0.00)
# Actual Value 9,111.90, Predicted value 9,111.90 (%0.00)
# Actual Value 8,992.80, Predicted value 8,992.80 (%0.00)
# Actual Value 9,313.90, Predicted value 9,313.90 (%0.00)
# Actual Value 9,859.90, Predicted value 9,859.90 (%0.00)
# Actual Value 9,199.05, Predicted value 9,199.05 (%0.00)
# Actual Value 9,142.75, Predicted value 9,142.75 (%0.00)
# Actual Value 9,106.25, Predicted value 9,106.25 (%0.00)
# Actual Value 9,490.10, Predicted value 9,490.10 (%0.00)
# Actual Value 10,029.10, Predicted value 10,029.10 (%0.00)
# Actual Value 9,902.00, Predicted value 9,902.00 (%0.00)
# Actual Value 10,091.65, Predicted value 10,091.65 (%0.00)
# Actual Value 10,288.90, Predicted value 10,288.90 (%0.00)
# Actual Value 10,551.70, Predicted value 10,551.70 (%0.00)
# Actual Value 10,813.45, Predicted value 10,813.45 (%0.00)
# Actual Value 10,739.95, Predicted value 10,739.95 (%0.00)
# Actual Value 11,215.45, Predicted value 11,215.45 (%0.00)
# Actual Value 11,102.15, Predicted value 11,102.15 (%0.00)
# Actual Value 11,200.15, Predicted value 11,200.15 (%0.00)
# Actual Value 11,300.45, Predicted value 11,300.45 (%0.00)
# Actual Value 11,312.20, Predicted value 11,312.20 (%0.00)
# Actual Value 11,559.25, Predicted value 11,559.25 (%0.00)
# Actual Value 11,527.45, Predicted value 11,527.45 (%0.00)
# Actual Value 11,449.25, Predicted value 11,449.25 (%0.00)
# Actual Value 11,516.10, Predicted value 11,516.10 (%0.00)
# Actual Value 10,805.55, Predicted value 10,805.55 (%0.00)
# Actual Value 11,416.95, Predicted value 11,416.95 (%0.00)
# Actual Value 11,834.60, Predicted value 11,834.60 (%0.00)
# Actual Value 11,680.35, Predicted value 11,680.35 (%0.00)
# Actual Value 11,896.45, Predicted value 11,896.45 (%0.00)
# Actual Value 11,670.80, Predicted value 11,670.80 (%0.00)
# Actual Value 12,120.30, Predicted value 12,120.30 (%0.00)
# Actual Value 12,690.80, Predicted value 12,690.80 (%0.00)
# Actual Value 12,771.70, Predicted value 12,771.70 (%0.00)
# Actual Value 12,987.00, Predicted value 12,987.00 (%0.00)
# Actual Value 13,133.90, Predicted value 13,133.90 (%0.00)
# Actual Value 13,478.30, Predicted value 13,478.30 (%0.00)
# Actual Value 13,740.70, Predicted value 13,740.70 (%0.00)
# Actual Value 13,749.25, Predicted value 13,749.25 (%0.00)
# Actual Value 13,981.75, Predicted value 13,981.75 (%0.00)
# Actual Value 14,146.25, Predicted value 14,146.25 (%0.00)
# Actual Value 14,188.90, Predicted value 14,188.90 (%-0.00)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_LR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_LR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_LR), 2)) 
print
("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_LR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_LR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 0.0
# Mean squared error = 0.0
# Median absolute error = 0.0
# R2 score = 1.0

# %%
# Plotting the results

r = range(len(y_pred_LR))

plt.title("Results Plot of LinearRegression")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_LR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend();

# %%
# Training our dataset using GradientBoostingRegressor as model

model_GBR = Pipeline([('scaler', StandardScaler()), ('model_GBR', GradientBoostingRegressor(random_state=0))])

model_GBR.fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_GBR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_GBR.score(x_test, y_test))

pickle.dump(model_GBR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_GBR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.99999
#
#
# Score on testing data:
# ========================================
# -1.61915

# %%
y_pred_GBR = model_GBR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_GBR)):
    expl=((actual_data[i]-y_pred_GBR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_GBR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,667.02 (%0.07)
# Actual Value $8,592.20, Predicted value $8,588.87 (%0.04)
# Actual Value $8,774.65, Predicted value $8,776.29 (%-0.02)
# Actual Value $8,952.50, Predicted value $8,948.08 (%0.05)
# Actual Value $8,742.55, Predicted value $8,761.15 (%-0.21)
# Actual Value $8,867.45, Predicted value $8,894.17 (%-0.30)
# Actual Value $8,591.25, Predicted value $8,590.04 (%0.01)
# Actual Value $8,709.55, Predicted value $8,711.76 (%-0.03)
# Actual Value $8,573.35, Predicted value $8,567.55 (%0.07)
# Actual Value $8,699.40, Predicted value $8,707.28 (%-0.09)
# Actual Value $8,615.25, Predicted value $8,609.40 (%0.07)
# Actual Value $8,484.95, Predicted value $8,497.13 (%-0.14)
# Actual Value $8,525.75, Predicted value $8,505.43 (%0.24)
# Actual Value $8,079.95, Predicted value $8,086.00 (%-0.07)
# Actual Value $7,965.50, Predicted value $7,957.78 (%0.10)
# Actual Value $8,192.90, Predicted value $8,203.59 (%-0.13)
# Actual Value $8,246.85, Predicted value $8,239.29 (%0.09)
# Actual Value $8,153.60, Predicted value $8,155.31 (%-0.02)
# Actual Value $7,979.10, Predicted value $7,961.64 (%0.22)
# Actual Value $8,103.60, Predicted value $8,081.51 (%0.27)
# Actual Value $8,273.80, Predicted value $8,273.45 (%0.00)
# Actual Value $8,407.20, Predicted value $8,402.87 (%0.05)
# Actual Value $8,435.10, Predicted value $8,453.72 (%-0.22)
# Actual Value $8,602.75, Predicted value $8,607.46 (%-0.05)
# Actual Value $8,734.25, Predicted value $8,711.51 (%0.26)
# Actual Value $8,778.40, Predicted value $8,815.85 (%-0.43)
# Actual Value $8,778.00, Predicted value $8,815.85 (%-0.43)
# Actual Value $8,939.50, Predicted value $8,942.78 (%-0.04)
# Actual Value $8,899.75, Predicted value $8,900.78 (%-0.01)
# Actual Value $8,927.00, Predicted value $8,942.68 (%-0.18)
# Actual Value $9,153.70, Predicted value $8,947.88 (%2.25)
# Actual Value $9,086.30, Predicted value $8,947.98 (%1.52)
# Actual Value $9,173.75, Predicted value $8,947.98 (%2.46)
# Actual Value $9,261.95, Predicted value $8,947.61 (%3.39)
# Actual Value $9,150.80, Predicted value $8,947.88 (%2.22)
# Actual Value $9,136.40, Predicted value $8,948.75 (%2.05)
# Actual Value $9,342.15, Predicted value $8,947.88 (%4.22)
# Actual Value $9,359.90, Predicted value $8,947.68 (%4.40)
# Actual Value $9,422.40, Predicted value $8,947.88 (%5.04)
# Actual Value $9,429.45, Predicted value $8,947.88 (%5.11)
# Actual Value $9,509.75, Predicted value $8,947.98 (%5.91)
# Actual Value $9,616.10, Predicted value $8,947.98 (%6.95)
# Actual Value $9,647.25, Predicted value $8,947.68 (%7.25)
# Actual Value $9,578.05, Predicted value $8,947.68 (%6.58)
# Actual Value $9,630.00, Predicted value $8,947.88 (%7.08)
# Actual Value $9,504.10, Predicted value $8,947.81 (%5.85)
# Actual Value $9,674.55, Predicted value $8,947.68 (%7.51)
# Actual Value $9,891.70, Predicted value $8,947.95 (%9.54)
# Actual Value $9,873.30, Predicted value $8,948.24 (%9.37)
# Actual Value $10,020.55, Predicted value $8,947.98 (%10.70)
# Actual Value $10,013.65, Predicted value $8,948.24 (%10.64)
# Actual Value $9,820.25, Predicted value $8,947.88 (%8.88)
# Actual Value $9,904.15, Predicted value $8,947.88 (%9.66)
# Actual Value $9,857.05, Predicted value $8,948.24 (%9.22)
# Actual Value $9,917.90, Predicted value $8,947.81 (%9.78)
# Actual Value $9,929.90, Predicted value $8,947.68 (%9.89)
# Actual Value $10,086.60, Predicted value $8,948.24 (%11.29)
# Actual Value $10,121.90, Predicted value $8,948.24 (%11.60)
# Actual Value $9,768.95, Predicted value $8,947.98 (%8.40)
# Actual Value $9,888.70, Predicted value $8,947.20 (%9.52)
# Actual Value $10,096.40, Predicted value $8,947.88 (%11.38)
# Actual Value $10,146.55, Predicted value $8,947.88 (%11.81)
# Actual Value $10,343.80, Predicted value $8,947.98 (%13.49)
# Actual Value $10,423.80, Predicted value $8,947.98 (%14.16)
# Actual Value $10,308.95, Predicted value $8,947.98 (%13.20)
# Actual Value $10,214.75, Predicted value $8,947.98 (%12.40)
# Actual Value $10,348.75, Predicted value $8,947.88 (%13.54)
# Actual Value $10,226.55, Predicted value $8,948.24 (%12.50)
# Actual Value $10,166.70, Predicted value $8,947.68 (%11.99)
# Actual Value $10,252.10, Predicted value $8,947.88 (%12.72)
# Actual Value $10,440.30, Predicted value $8,948.24 (%14.29)
# Actual Value $10,477.90, Predicted value $8,947.68 (%14.60)
# Actual Value $10,504.80, Predicted value $8,947.20 (%14.83)
# Actual Value $10,651.20, Predicted value $8,947.88 (%15.99)
# Actual Value $10,817.00, Predicted value $8,947.98 (%17.28)
# Actual Value $11,069.65, Predicted value $8,947.98 (%19.17)
# Actual Value $11,016.90, Predicted value $8,947.98 (%18.78)
# Actual Value $10,576.85, Predicted value $8,947.98 (%15.40)
# Actual Value $10,545.50, Predicted value $8,947.88 (%15.15)
# Actual Value $10,382.70, Predicted value $8,947.98 (%13.82)
# Actual Value $10,458.35, Predicted value $8,947.98 (%14.44)
# Actual Value $10,242.65, Predicted value $8,947.88 (%12.64)
# Actual Value $10,360.15, Predicted value $8,947.98 (%13.63)
# Actual Value $10,114.75, Predicted value $8,947.98 (%11.54)
# Actual Value $10,113.70, Predicted value $8,947.98 (%11.53)
# Actual Value $10,325.15, Predicted value $8,947.88 (%13.34)
# Actual Value $10,458.65, Predicted value $8,947.98 (%14.44)
# Actual Value $10,565.30, Predicted value $8,947.98 (%15.31)
# Actual Value $10,617.80, Predicted value $8,947.98 (%15.73)
# Actual Value $10,679.65, Predicted value $8,947.68 (%16.22)
# Actual Value $10,716.55, Predicted value $8,947.98 (%16.50)
# Actual Value $10,682.70, Predicted value $8,947.98 (%16.24)
# Actual Value $10,513.85, Predicted value $8,947.98 (%14.89)
# Actual Value $10,736.15, Predicted value $8,947.98 (%16.66)
# Actual Value $10,768.35, Predicted value $8,948.24 (%16.90)
# Actual Value $10,808.05, Predicted value $8,947.98 (%17.21)
# Actual Value $10,741.10, Predicted value $8,947.98 (%16.69)
# Actual Value $10,589.10, Predicted value $8,947.98 (%15.50)
# Actual Value $10,749.75, Predicted value $8,947.98 (%16.76)
# Actual Value $11,023.20, Predicted value $8,947.88 (%18.83)
# Actual Value $10,957.10, Predicted value $8,947.88 (%18.34)
# Actual Value $11,167.30, Predicted value $8,947.98 (%19.87)
# Actual Value $11,244.70, Predicted value $8,947.98 (%20.42)
# Actual Value $11,470.70, Predicted value $8,947.98 (%21.99)
# Actual Value $11,385.05, Predicted value $8,947.68 (%21.41)
# Actual Value $11,582.75, Predicted value $8,947.88 (%22.75)
# Actual Value $11,676.80, Predicted value $8,947.98 (%23.37)
# Actual Value $11,536.90, Predicted value $8,947.98 (%22.44)
# Actual Value $11,369.90, Predicted value $8,947.88 (%21.30)
# Actual Value $11,234.35, Predicted value $8,948.24 (%20.35)
# Actual Value $10,977.55, Predicted value $8,947.98 (%18.49)
# Actual Value $10,599.25, Predicted value $8,947.98 (%15.58)
# Actual Value $10,234.65, Predicted value $8,947.98 (%12.57)
# Actual Value $10,453.05, Predicted value $8,947.98 (%14.40)
# Actual Value $10,124.90, Predicted value $8,947.98 (%11.62)
# Actual Value $10,380.45, Predicted value $8,947.98 (%13.80)
# Actual Value $10,598.40, Predicted value $8,947.68 (%15.58)
# Actual Value $10,616.70, Predicted value $8,947.98 (%15.72)
# Actual Value $10,526.75, Predicted value $8,947.98 (%15.00)
# Actual Value $10,858.70, Predicted value $8,947.98 (%17.60)
# Actual Value $10,601.15, Predicted value $8,947.98 (%15.59)
# Actual Value $10,791.55, Predicted value $8,947.98 (%17.08)
# Actual Value $10,951.70, Predicted value $8,947.98 (%18.30)
# Actual Value $10,779.80, Predicted value $8,947.98 (%16.99)
# Actual Value $10,672.25, Predicted value $8,947.98 (%16.16)
# Actual Value $10,821.60, Predicted value $8,947.98 (%17.31)
# Actual Value $10,905.20, Predicted value $8,947.98 (%17.95)
# Actual Value $10,849.80, Predicted value $8,947.98 (%17.53)
# Actual Value $10,830.95, Predicted value $8,947.98 (%17.39)
# Actual Value $11,069.40, Predicted value $8,947.98 (%19.16)
# Actual Value $10,746.05, Predicted value $8,947.98 (%16.73)
# Actual Value $10,789.85, Predicted value $8,947.98 (%17.07)
# Actual Value $10,792.50, Predicted value $8,947.98 (%17.09)
# Actual Value $11,058.20, Predicted value $8,947.98 (%19.08)
# Actual Value $11,343.25, Predicted value $8,947.98 (%21.12)
# Actual Value $11,521.05, Predicted value $8,947.98 (%22.33)
# Actual Value $11,570.00, Predicted value $8,947.98 (%22.66)
# Actual Value $11,598.00, Predicted value $8,947.98 (%22.85)
# Actual Value $11,596.70, Predicted value $8,947.98 (%22.84)
# Actual Value $11,752.80, Predicted value $8,947.98 (%23.87)
# Actual Value $11,641.80, Predicted value $8,947.98 (%23.14)
# Actual Value $11,724.75, Predicted value $8,947.98 (%23.68)
# Actual Value $11,301.80, Predicted value $8,947.98 (%20.83)
# Actual Value $11,257.10, Predicted value $8,947.98 (%20.51)
# Actual Value $11,657.05, Predicted value $8,947.98 (%23.24)
# Actual Value $11,945.90, Predicted value $8,947.98 (%25.10)
# Actual Value $11,843.75, Predicted value $8,947.98 (%24.45)
# Actual Value $11,914.05, Predicted value $8,947.98 (%24.90)
# Actual Value $11,831.75, Predicted value $8,947.98 (%24.37)
# Actual Value $11,841.55, Predicted value $8,947.98 (%24.44)
# Actual Value $11,946.75, Predicted value $8,947.98 (%25.10)
# Actual Value $11,582.90, Predicted value $8,947.98 (%22.75)
# Actual Value $11,596.90, Predicted value $8,947.98 (%22.84)
# Actual Value $11,252.15, Predicted value $8,947.98 (%20.48)
# Actual Value $10,980.00, Predicted value $8,947.98 (%18.51)
# Actual Value $11,032.45, Predicted value $8,947.98 (%18.89)
# Actual Value $11,029.40, Predicted value $8,947.98 (%18.87)
# Actual Value $10,741.35, Predicted value $8,947.98 (%16.70)
# Actual Value $10,948.30, Predicted value $8,947.98 (%18.27)
# Actual Value $10,847.90, Predicted value $8,947.98 (%17.51)
# Actual Value $10,982.80, Predicted value $8,947.98 (%18.53)
# Actual Value $10,704.80, Predicted value $8,947.98 (%16.41)
# Actual Value $11,571.20, Predicted value $8,947.98 (%22.67)
# Actual Value $11,314.00, Predicted value $8,947.98 (%20.91)
# Actual Value $11,234.55, Predicted value $8,947.98 (%20.35)
# Actual Value $11,586.35, Predicted value $8,947.98 (%22.77)
# Actual Value $11,582.60, Predicted value $8,947.98 (%22.75)
# Actual Value $11,877.45, Predicted value $8,947.98 (%24.66)
# Actual Value $12,012.05, Predicted value $8,947.98 (%25.51)
# Actual Value $11,872.10, Predicted value $8,947.98 (%24.63)
# Actual Value $11,968.40, Predicted value $8,947.98 (%25.24)
# Actual Value $12,151.15, Predicted value $8,947.98 (%26.36)
# Actual Value $12,018.40, Predicted value $8,947.98 (%25.55)
# Actual Value $11,971.80, Predicted value $8,947.98 (%25.26)
# Actual Value $12,259.70, Predicted value $8,947.98 (%27.01)
# Actual Value $12,126.55, Predicted value $8,947.98 (%26.21)
# Actual Value $12,282.20, Predicted value $8,947.98 (%27.15)
# Actual Value $12,215.90, Predicted value $8,947.98 (%26.75)
# Actual Value $12,355.50, Predicted value $8,947.98 (%27.58)
# Actual Value $12,180.35, Predicted value $8,947.98 (%26.54)
# Actual Value $12,035.80, Predicted value $8,947.98 (%25.66)
# Actual Value $12,137.95, Predicted value $8,947.98 (%26.28)
# Actual Value $12,174.65, Predicted value $8,947.98 (%26.50)
# Actual Value $12,080.85, Predicted value $8,947.98 (%25.93)
# Actual Value $11,633.30, Predicted value $8,947.98 (%23.08)
# Actual Value $11,269.00, Predicted value $8,947.98 (%20.60)
# Actual Value $9,590.15, Predicted value $8,947.98 (%6.70)
# Actual Value $8,263.45, Predicted value $8,271.99 (%-0.10)
# Actual Value $8,641.45, Predicted value $8,627.70 (%0.16)
# Actual Value $8,253.80, Predicted value $8,246.10 (%0.09)
# Actual Value $9,111.90, Predicted value $8,885.58 (%2.48)
# Actual Value $8,992.80, Predicted value $8,947.98 (%0.50)
# Actual Value $9,313.90, Predicted value $8,947.98 (%3.93)
# Actual Value $9,859.90, Predicted value $8,947.98 (%9.25)
# Actual Value $9,199.05, Predicted value $8,947.98 (%2.73)
# Actual Value $9,142.75, Predicted value $8,947.98 (%2.13)
# Actual Value $9,106.25, Predicted value $8,947.98 (%1.74)
# Actual Value $9,490.10, Predicted value $8,947.98 (%5.71)
# Actual Value $10,029.10, Predicted value $8,947.98 (%10.78)
# Actual Value $9,902.00, Predicted value $8,947.98 (%9.63)
# Actual Value $10,091.65, Predicted value $8,947.98 (%11.33)
# Actual Value $10,288.90, Predicted value $8,947.98 (%13.03)
# Actual Value $10,551.70, Predicted value $8,947.98 (%15.20)
# Actual Value $10,813.45, Predicted value $8,947.98 (%17.25)
# Actual Value $10,739.95, Predicted value $8,947.98 (%16.69)
# Actual Value $11,215.45, Predicted value $8,947.98 (%20.22)
# Actual Value $11,102.15, Predicted value $8,947.98 (%19.40)
# Actual Value $11,200.15, Predicted value $8,947.98 (%20.11)
# Actual Value $11,300.45, Predicted value $8,947.98 (%20.82)
# Actual Value $11,312.20, Predicted value $8,947.98 (%20.90)
# Actual Value $11,559.25, Predicted value $8,947.98 (%22.59)
# Actual Value $11,527.45, Predicted value $8,947.98 (%22.38)
# Actual Value $11,449.25, Predicted value $8,947.98 (%21.85)
# Actual Value $11,516.10, Predicted value $8,947.98 (%22.30)
# Actual Value $10,805.55, Predicted value $8,947.98 (%17.19)
# Actual Value $11,416.95, Predicted value $8,947.98 (%21.63)
# Actual Value $11,834.60, Predicted value $8,947.98 (%24.39)
# Actual Value $11,680.35, Predicted value $8,947.98 (%23.39)
# Actual Value $11,896.45, Predicted value $8,947.98 (%24.78)
# Actual Value $11,670.80, Predicted value $8,947.98 (%23.33)
# Actual Value $12,120.30, Predicted value $8,947.98 (%26.17)
# Actual Value $12,690.80, Predicted value $8,947.98 (%29.49)
# Actual Value $12,771.70, Predicted value $8,947.98 (%29.94)
# Actual Value $12,987.00, Predicted value $8,947.98 (%31.10)
# Actual Value $13,133.90, Predicted value $8,947.98 (%31.87)
# Actual Value $13,478.30, Predicted value $8,947.98 (%33.61)
# Actual Value $13,740.70, Predicted value $8,947.98 (%34.88)
# Actual Value $13,749.25, Predicted value $8,947.98 (%34.92)
# Actual Value $13,981.75, Predicted value $8,947.98 (%36.00)
# Actual Value $14,146.25, Predicted value $8,947.98 (%36.75)
# Actual Value $14,188.90, Predicted value $8,946.13 (%36.95)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_GBR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_GBR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_GBR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_GBR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_GBR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 1684.14
# Mean squared error = 4198692.58
# Median absolute error = 1731.97
# Explain variance score = 0.15
# R2 score = -1.62

# %%
# Plotting the results

r = range(len(y_pred_GBR))

plt.title("Results Plot of GradientBoostingRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_GBR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using RandomForestRegressor as model

model_RFR = Pipeline([('scaler', StandardScaler()), ('model_RFR', RandomForestRegressor(random_state=0))])
model_RFR.fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_RFR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_RFR.score(x_test, y_test))

pickle.dump(model_RFR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_RFR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.99996
#
#
# Score on testing data:
# ========================================
# -1.66396

# %%
y_pred_RFR = model_RFR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_RFR)):
    expl=((actual_data[i]-y_pred_RFR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_RFR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,675.85 (%-0.03)
# Actual Value $8,592.20, Predicted value $8,594.29 (%-0.02)
# Actual Value $8,774.65, Predicted value $8,769.69 (%0.06)
# Actual Value $8,952.50, Predicted value $8,921.24 (%0.35)
# Actual Value $8,742.55, Predicted value $8,773.61 (%-0.36)
# Actual Value $8,867.45, Predicted value $8,884.00 (%-0.19)
# Actual Value $8,591.25, Predicted value $8,612.60 (%-0.25)
# Actual Value $8,709.55, Predicted value $8,716.45 (%-0.08)
# Actual Value $8,573.35, Predicted value $8,583.92 (%-0.12)
# Actual Value $8,699.40, Predicted value $8,700.39 (%-0.01)
# Actual Value $8,615.25, Predicted value $8,614.01 (%0.01)
# Actual Value $8,484.95, Predicted value $8,521.17 (%-0.43)
# Actual Value $8,525.75, Predicted value $8,519.13 (%0.08)
# Actual Value $8,079.95, Predicted value $8,090.00 (%-0.12)
# Actual Value $7,965.50, Predicted value $7,961.87 (%0.05)
# Actual Value $8,192.90, Predicted value $8,191.60 (%0.02)
# Actual Value $8,246.85, Predicted value $8,236.48 (%0.13)
# Actual Value $8,153.60, Predicted value $8,159.39 (%-0.07)
# Actual Value $7,979.10, Predicted value $7,963.27 (%0.20)
# Actual Value $8,103.60, Predicted value $8,095.40 (%0.10)
# Actual Value $8,273.80, Predicted value $8,274.43 (%-0.01)
# Actual Value $8,407.20, Predicted value $8,402.30 (%0.06)
# Actual Value $8,435.10, Predicted value $8,424.32 (%0.13)
# Actual Value $8,602.75, Predicted value $8,596.01 (%0.08)
# Actual Value $8,734.25, Predicted value $8,721.41 (%0.15)
# Actual Value $8,778.40, Predicted value $8,831.82 (%-0.61)
# Actual Value $8,778.00, Predicted value $8,832.48 (%-0.62)
# Actual Value $8,939.50, Predicted value $8,922.02 (%0.20)
# Actual Value $8,899.75, Predicted value $8,910.30 (%-0.12)
# Actual Value $8,927.00, Predicted value $8,917.55 (%0.11)
# Actual Value $9,153.70, Predicted value $8,920.41 (%2.55)
# Actual Value $9,086.30, Predicted value $8,927.84 (%1.74)
# Actual Value $9,173.75, Predicted value $8,927.84 (%2.68)
# Actual Value $9,261.95, Predicted value $8,916.73 (%3.73)
# Actual Value $9,150.80, Predicted value $8,920.41 (%2.52)
# Actual Value $9,136.40, Predicted value $8,913.77 (%2.44)
# Actual Value $9,342.15, Predicted value $8,923.38 (%4.48)
# Actual Value $9,359.90, Predicted value $8,916.41 (%4.74)
# Actual Value $9,422.40, Predicted value $8,920.41 (%5.33)
# Actual Value $9,429.45, Predicted value $8,920.41 (%5.40)
# Actual Value $9,509.75, Predicted value $8,927.84 (%6.12)
# Actual Value $9,616.10, Predicted value $8,927.84 (%7.16)
# Actual Value $9,647.25, Predicted value $8,915.77 (%7.58)
# Actual Value $9,578.05, Predicted value $8,920.41 (%6.87)
# Actual Value $9,630.00, Predicted value $8,920.41 (%7.37)
# Actual Value $9,504.10, Predicted value $8,920.41 (%6.14)
# Actual Value $9,674.55, Predicted value $8,920.41 (%7.80)
# Actual Value $9,891.70, Predicted value $8,913.77 (%9.89)
# Actual Value $9,873.30, Predicted value $8,927.84 (%9.58)
# Actual Value $10,020.55, Predicted value $8,927.84 (%10.90)
# Actual Value $10,013.65, Predicted value $8,927.84 (%10.84)
# Actual Value $9,820.25, Predicted value $8,923.38 (%9.13)
# Actual Value $9,904.15, Predicted value $8,923.38 (%9.90)
# Actual Value $9,857.05, Predicted value $8,927.84 (%9.43)
# Actual Value $9,917.90, Predicted value $8,920.41 (%10.06)
# Actual Value $9,929.90, Predicted value $8,920.41 (%10.17)
# Actual Value $10,086.60, Predicted value $8,927.84 (%11.49)
# Actual Value $10,121.90, Predicted value $8,927.84 (%11.80)
# Actual Value $9,768.95, Predicted value $8,927.84 (%8.61)
# Actual Value $9,888.70, Predicted value $8,913.77 (%9.86)
# Actual Value $10,096.40, Predicted value $8,920.41 (%11.65)
# Actual Value $10,146.55, Predicted value $8,923.38 (%12.06)
# Actual Value $10,343.80, Predicted value $8,927.84 (%13.69)
# Actual Value $10,423.80, Predicted value $8,927.84 (%14.35)
# Actual Value $10,308.95, Predicted value $8,927.84 (%13.40)
# Actual Value $10,214.75, Predicted value $8,927.84 (%12.60)
# Actual Value $10,348.75, Predicted value $8,920.41 (%13.80)
# Actual Value $10,226.55, Predicted value $8,927.84 (%12.70)
# Actual Value $10,166.70, Predicted value $8,920.41 (%12.26)
# Actual Value $10,252.10, Predicted value $8,920.41 (%12.99)
# Actual Value $10,440.30, Predicted value $8,927.84 (%14.49)
# Actual Value $10,477.90, Predicted value $8,916.56 (%14.90)
# Actual Value $10,504.80, Predicted value $8,913.77 (%15.15)
# Actual Value $10,651.20, Predicted value $8,920.41 (%16.25)
# Actual Value $10,817.00, Predicted value $8,927.84 (%17.46)
# Actual Value $11,069.65, Predicted value $8,927.84 (%19.35)
# Actual Value $11,016.90, Predicted value $8,927.84 (%18.96)
# Actual Value $10,576.85, Predicted value $8,927.84 (%15.59)
# Actual Value $10,545.50, Predicted value $8,920.41 (%15.41)
# Actual Value $10,382.70, Predicted value $8,927.84 (%14.01)
# Actual Value $10,458.35, Predicted value $8,927.84 (%14.63)
# Actual Value $10,242.65, Predicted value $8,923.38 (%12.88)
# Actual Value $10,360.15, Predicted value $8,927.84 (%13.83)
# Actual Value $10,114.75, Predicted value $8,927.84 (%11.73)
# Actual Value $10,113.70, Predicted value $8,927.84 (%11.73)
# Actual Value $10,325.15, Predicted value $8,923.38 (%13.58)
# Actual Value $10,458.65, Predicted value $8,927.84 (%14.64)
# Actual Value $10,565.30, Predicted value $8,927.84 (%15.50)
# Actual Value $10,617.80, Predicted value $8,927.84 (%15.92)
# Actual Value $10,679.65, Predicted value $8,913.77 (%16.53)
# Actual Value $10,716.55, Predicted value $8,927.84 (%16.69)
# Actual Value $10,682.70, Predicted value $8,927.84 (%16.43)
# Actual Value $10,513.85, Predicted value $8,927.84 (%15.08)
# Actual Value $10,736.15, Predicted value $8,927.84 (%16.84)
# Actual Value $10,768.35, Predicted value $8,927.84 (%17.09)
# Actual Value $10,808.05, Predicted value $8,927.84 (%17.40)
# Actual Value $10,741.10, Predicted value $8,927.84 (%16.88)
# Actual Value $10,589.10, Predicted value $8,927.84 (%15.69)
# Actual Value $10,749.75, Predicted value $8,927.84 (%16.95)
# Actual Value $11,023.20, Predicted value $8,920.41 (%19.08)
# Actual Value $10,957.10, Predicted value $8,920.41 (%18.59)
# Actual Value $11,167.30, Predicted value $8,927.84 (%20.05)
# Actual Value $11,244.70, Predicted value $8,927.84 (%20.60)
# Actual Value $11,470.70, Predicted value $8,927.84 (%22.17)
# Actual Value $11,385.05, Predicted value $8,914.85 (%21.70)
# Actual Value $11,582.75, Predicted value $8,923.68 (%22.96)
# Actual Value $11,676.80, Predicted value $8,927.84 (%23.54)
# Actual Value $11,536.90, Predicted value $8,927.84 (%22.61)
# Actual Value $11,369.90, Predicted value $8,920.41 (%21.54)
# Actual Value $11,234.35, Predicted value $8,927.84 (%20.53)
# Actual Value $10,977.55, Predicted value $8,927.84 (%18.67)
# Actual Value $10,599.25, Predicted value $8,927.84 (%15.77)
# Actual Value $10,234.65, Predicted value $8,927.84 (%12.77)
# Actual Value $10,453.05, Predicted value $8,927.84 (%14.59)
# Actual Value $10,124.90, Predicted value $8,927.84 (%11.82)
# Actual Value $10,380.45, Predicted value $8,927.84 (%13.99)
# Actual Value $10,598.40, Predicted value $8,914.85 (%15.88)
# Actual Value $10,616.70, Predicted value $8,927.84 (%15.91)
# Actual Value $10,526.75, Predicted value $8,927.84 (%15.19)
# Actual Value $10,858.70, Predicted value $8,927.84 (%17.78)
# Actual Value $10,601.15, Predicted value $8,927.84 (%15.78)
# Actual Value $10,791.55, Predicted value $8,927.84 (%17.27)
# Actual Value $10,951.70, Predicted value $8,927.84 (%18.48)
# Actual Value $10,779.80, Predicted value $8,927.84 (%17.18)
# Actual Value $10,672.25, Predicted value $8,927.84 (%16.35)
# Actual Value $10,821.60, Predicted value $8,927.84 (%17.50)
# Actual Value $10,905.20, Predicted value $8,927.84 (%18.13)
# Actual Value $10,849.80, Predicted value $8,927.84 (%17.71)
# Actual Value $10,830.95, Predicted value $8,927.84 (%17.57)
# Actual Value $11,069.40, Predicted value $8,927.84 (%19.35)
# Actual Value $10,746.05, Predicted value $8,927.84 (%16.92)
# Actual Value $10,789.85, Predicted value $8,927.84 (%17.26)
# Actual Value $10,792.50, Predicted value $8,927.84 (%17.28)
# Actual Value $11,058.20, Predicted value $8,927.84 (%19.26)
# Actual Value $11,343.25, Predicted value $8,927.84 (%21.29)
# Actual Value $11,521.05, Predicted value $8,927.84 (%22.51)
# Actual Value $11,570.00, Predicted value $8,927.84 (%22.84)
# Actual Value $11,598.00, Predicted value $8,927.84 (%23.02)
# Actual Value $11,596.70, Predicted value $8,927.84 (%23.01)
# Actual Value $11,752.80, Predicted value $8,927.84 (%24.04)
# Actual Value $11,641.80, Predicted value $8,927.84 (%23.31)
# Actual Value $11,724.75, Predicted value $8,927.84 (%23.85)
# Actual Value $11,301.80, Predicted value $8,927.84 (%21.01)
# Actual Value $11,257.10, Predicted value $8,927.84 (%20.69)
# Actual Value $11,657.05, Predicted value $8,927.84 (%23.41)
# Actual Value $11,945.90, Predicted value $8,927.84 (%25.26)
# Actual Value $11,843.75, Predicted value $8,927.84 (%24.62)
# Actual Value $11,914.05, Predicted value $8,927.84 (%25.06)
# Actual Value $11,831.75, Predicted value $8,927.84 (%24.54)
# Actual Value $11,841.55, Predicted value $8,927.84 (%24.61)
# Actual Value $11,946.75, Predicted value $8,927.84 (%25.27)
# Actual Value $11,582.90, Predicted value $8,927.84 (%22.92)
# Actual Value $11,596.90, Predicted value $8,927.84 (%23.02)
# Actual Value $11,252.15, Predicted value $8,927.84 (%20.66)
# Actual Value $10,980.00, Predicted value $8,927.84 (%18.69)
# Actual Value $11,032.45, Predicted value $8,927.84 (%19.08)
# Actual Value $11,029.40, Predicted value $8,927.84 (%19.05)
# Actual Value $10,741.35, Predicted value $8,927.84 (%16.88)
# Actual Value $10,948.30, Predicted value $8,927.84 (%18.45)
# Actual Value $10,847.90, Predicted value $8,927.84 (%17.70)
# Actual Value $10,982.80, Predicted value $8,927.84 (%18.71)
# Actual Value $10,704.80, Predicted value $8,927.84 (%16.60)
# Actual Value $11,571.20, Predicted value $8,927.84 (%22.84)
# Actual Value $11,314.00, Predicted value $8,927.84 (%21.09)
# Actual Value $11,234.55, Predicted value $8,927.84 (%20.53)
# Actual Value $11,586.35, Predicted value $8,927.84 (%22.95)
# Actual Value $11,582.60, Predicted value $8,927.84 (%22.92)
# Actual Value $11,877.45, Predicted value $8,927.84 (%24.83)
# Actual Value $12,012.05, Predicted value $8,927.84 (%25.68)
# Actual Value $11,872.10, Predicted value $8,927.84 (%24.80)
# Actual Value $11,968.40, Predicted value $8,927.84 (%25.40)
# Actual Value $12,151.15, Predicted value $8,927.84 (%26.53)
# Actual Value $12,018.40, Predicted value $8,927.84 (%25.72)
# Actual Value $11,971.80, Predicted value $8,927.84 (%25.43)
# Actual Value $12,259.70, Predicted value $8,927.84 (%27.18)
# Actual Value $12,126.55, Predicted value $8,927.84 (%26.38)
# Actual Value $12,282.20, Predicted value $8,927.84 (%27.31)
# Actual Value $12,215.90, Predicted value $8,927.84 (%26.92)
# Actual Value $12,355.50, Predicted value $8,927.84 (%27.74)
# Actual Value $12,180.35, Predicted value $8,927.84 (%26.70)
# Actual Value $12,035.80, Predicted value $8,927.84 (%25.82)
# Actual Value $12,137.95, Predicted value $8,927.84 (%26.45)
# Actual Value $12,174.65, Predicted value $8,927.84 (%26.67)
# Actual Value $12,080.85, Predicted value $8,927.84 (%26.10)
# Actual Value $11,633.30, Predicted value $8,927.84 (%23.26)
# Actual Value $11,269.00, Predicted value $8,927.84 (%20.78)
# Actual Value $9,590.15, Predicted value $8,927.84 (%6.91)
# Actual Value $8,263.45, Predicted value $8,266.95 (%-0.04)
# Actual Value $8,641.45, Predicted value $8,629.01 (%0.14)
# Actual Value $8,253.80, Predicted value $8,266.16 (%-0.15)
# Actual Value $9,111.90, Predicted value $8,850.03 (%2.87)
# Actual Value $8,992.80, Predicted value $8,927.84 (%0.72)
# Actual Value $9,313.90, Predicted value $8,927.84 (%4.14)
# Actual Value $9,859.90, Predicted value $8,927.84 (%9.45)
# Actual Value $9,199.05, Predicted value $8,927.84 (%2.95)
# Actual Value $9,142.75, Predicted value $8,927.84 (%2.35)
# Actual Value $9,106.25, Predicted value $8,927.84 (%1.96)
# Actual Value $9,490.10, Predicted value $8,927.84 (%5.92)
# Actual Value $10,029.10, Predicted value $8,927.84 (%10.98)
# Actual Value $9,902.00, Predicted value $8,927.84 (%9.84)
# Actual Value $10,091.65, Predicted value $8,927.84 (%11.53)
# Actual Value $10,288.90, Predicted value $8,927.84 (%13.23)
# Actual Value $10,551.70, Predicted value $8,927.84 (%15.39)
# Actual Value $10,813.45, Predicted value $8,927.84 (%17.44)
# Actual Value $10,739.95, Predicted value $8,927.84 (%16.87)
# Actual Value $11,215.45, Predicted value $8,927.84 (%20.40)
# Actual Value $11,102.15, Predicted value $8,927.84 (%19.58)
# Actual Value $11,200.15, Predicted value $8,927.84 (%20.29)
# Actual Value $11,300.45, Predicted value $8,927.84 (%21.00)
# Actual Value $11,312.20, Predicted value $8,927.84 (%21.08)
# Actual Value $11,559.25, Predicted value $8,927.84 (%22.76)
# Actual Value $11,527.45, Predicted value $8,927.84 (%22.55)
# Actual Value $11,449.25, Predicted value $8,927.84 (%22.02)
# Actual Value $11,516.10, Predicted value $8,927.84 (%22.48)
# Actual Value $10,805.55, Predicted value $8,927.84 (%17.38)
# Actual Value $11,416.95, Predicted value $8,927.84 (%21.80)
# Actual Value $11,834.60, Predicted value $8,927.84 (%24.56)
# Actual Value $11,680.35, Predicted value $8,927.84 (%23.57)
# Actual Value $11,896.45, Predicted value $8,927.84 (%24.95)
# Actual Value $11,670.80, Predicted value $8,927.84 (%23.50)
# Actual Value $12,120.30, Predicted value $8,927.84 (%26.34)
# Actual Value $12,690.80, Predicted value $8,927.84 (%29.65)
# Actual Value $12,771.70, Predicted value $8,927.84 (%30.10)
# Actual Value $12,987.00, Predicted value $8,927.84 (%31.26)
# Actual Value $13,133.90, Predicted value $8,927.84 (%32.02)
# Actual Value $13,478.30, Predicted value $8,927.84 (%33.76)
# Actual Value $13,740.70, Predicted value $8,927.84 (%35.03)
# Actual Value $13,749.25, Predicted value $8,927.84 (%35.07)
# Actual Value $13,981.75, Predicted value $8,927.84 (%36.15)
# Actual Value $14,146.25, Predicted value $8,927.84 (%36.89)
# Actual Value $14,188.90, Predicted value $8,913.77 (%37.18)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_RFR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_RFR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_RFR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_RFR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_RFR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 1703.17
# Mean squared error = 4270521.78
# Median absolute error = 1754.86
# Explain variance score = 0.14
# R2 score = -1.66

# %%
# Plotting the results

r = range(len(y_pred_RFR))

plt.title("Results Plot of RandomForestRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_RFR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using SupportVectorRegressor as model

model_SVR = Pipeline([('scaler', StandardScaler()), ('model_SVR', SVR())])
model_SVR.fit(x_train, y_train)
# model_SVR = SVR().fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_SVR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_SVR.score(x_test, y_test))

pickle.dump(model_SVR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_SVR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.01958
#
#
# Score on testing data:
# ========================================
# -12.79333

# %%
y_pred_SVR = model_SVR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_SVR)):
    expl=((actual_data[i]-y_pred_SVR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_SVR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $6,116.17 (%29.48)
# Actual Value $8,592.20, Predicted value $6,120.05 (%28.77)
# Actual Value $8,774.65, Predicted value $6,113.57 (%30.33)
# Actual Value $8,952.50, Predicted value $6,108.22 (%31.77)
# Actual Value $8,742.55, Predicted value $6,111.09 (%30.10)
# Actual Value $8,867.45, Predicted value $6,111.52 (%31.08)
# Actual Value $8,591.25, Predicted value $6,110.84 (%28.87)
# Actual Value $8,709.55, Predicted value $6,120.04 (%29.73)
# Actual Value $8,573.35, Predicted value $6,112.56 (%28.70)
# Actual Value $8,699.40, Predicted value $6,120.21 (%29.65)
# Actual Value $8,615.25, Predicted value $6,117.63 (%28.99)
# Actual Value $8,484.95, Predicted value $6,123.43 (%27.83)
# Actual Value $8,525.75, Predicted value $6,115.43 (%28.27)
# Actual Value $8,079.95, Predicted value $6,124.48 (%24.20)
# Actual Value $7,965.50, Predicted value $6,131.16 (%23.03)
# Actual Value $8,192.90, Predicted value $6,133.53 (%25.14)
# Actual Value $8,246.85, Predicted value $6,135.61 (%25.60)
# Actual Value $8,153.60, Predicted value $6,135.52 (%24.75)
# Actual Value $7,979.10, Predicted value $6,135.56 (%23.10)
# Actual Value $8,103.60, Predicted value $6,135.02 (%24.29)
# Actual Value $8,273.80, Predicted value $6,134.01 (%25.86)
# Actual Value $8,407.20, Predicted value $6,132.61 (%27.06)
# Actual Value $8,435.10, Predicted value $6,129.72 (%27.33)
# Actual Value $8,602.75, Predicted value $6,126.95 (%28.78)
# Actual Value $8,734.25, Predicted value $6,067.62 (%30.53)
# Actual Value $8,778.40, Predicted value $6,110.52 (%30.39)
# Actual Value $8,778.00, Predicted value $6,109.36 (%30.40)
# Actual Value $8,939.50, Predicted value $6,090.95 (%31.86)
# Actual Value $8,899.75, Predicted value $6,104.96 (%31.40)
# Actual Value $8,927.00, Predicted value $6,105.88 (%31.60)
# Actual Value $9,153.70, Predicted value $6,098.77 (%33.37)
# Actual Value $9,086.30, Predicted value $6,079.04 (%33.10)
# Actual Value $9,173.75, Predicted value $6,085.99 (%33.66)
# Actual Value $9,261.95, Predicted value $6,089.11 (%34.26)
# Actual Value $9,150.80, Predicted value $6,090.22 (%33.45)
# Actual Value $9,136.40, Predicted value $6,089.34 (%33.35)
# Actual Value $9,342.15, Predicted value $6,086.84 (%34.85)
# Actual Value $9,359.90, Predicted value $6,082.30 (%35.02)
# Actual Value $9,422.40, Predicted value $6,079.43 (%35.48)
# Actual Value $9,429.45, Predicted value $6,075.97 (%35.56)
# Actual Value $9,509.75, Predicted value $6,068.53 (%36.19)
# Actual Value $9,616.10, Predicted value $6,061.89 (%36.96)
# Actual Value $9,647.25, Predicted value $6,064.96 (%37.13)
# Actual Value $9,578.05, Predicted value $6,067.32 (%36.65)
# Actual Value $9,630.00, Predicted value $6,066.65 (%37.00)
# Actual Value $9,504.10, Predicted value $6,069.61 (%36.14)
# Actual Value $9,674.55, Predicted value $6,069.19 (%37.27)
# Actual Value $9,891.70, Predicted value $6,059.46 (%38.74)
# Actual Value $9,873.30, Predicted value $6,054.49 (%38.68)
# Actual Value $10,020.55, Predicted value $6,050.64 (%39.62)
# Actual Value $10,013.65, Predicted value $6,049.42 (%39.59)
# Actual Value $9,820.25, Predicted value $6,053.18 (%38.36)
# Actual Value $9,904.15, Predicted value $6,057.72 (%38.84)
# Actual Value $9,857.05, Predicted value $6,055.93 (%38.56)
# Actual Value $9,917.90, Predicted value $6,055.21 (%38.95)
# Actual Value $9,929.90, Predicted value $6,053.50 (%39.04)
# Actual Value $10,086.60, Predicted value $6,049.49 (%40.02)
# Actual Value $10,121.90, Predicted value $6,046.72 (%40.26)
# Actual Value $9,768.95, Predicted value $6,049.59 (%38.07)
# Actual Value $9,888.70, Predicted value $6,056.02 (%38.76)
# Actual Value $10,096.40, Predicted value $6,050.56 (%40.07)
# Actual Value $10,146.55, Predicted value $6,045.55 (%40.42)
# Actual Value $10,343.80, Predicted value $6,038.39 (%41.62)
# Actual Value $10,423.80, Predicted value $6,038.27 (%42.07)
# Actual Value $10,308.95, Predicted value $6,038.74 (%41.42)
# Actual Value $10,214.75, Predicted value $6,041.60 (%40.85)
# Actual Value $10,348.75, Predicted value $6,041.55 (%41.62)
# Actual Value $10,226.55, Predicted value $6,041.74 (%40.92)
# Actual Value $10,166.70, Predicted value $6,045.20 (%40.54)
# Actual Value $10,252.10, Predicted value $6,043.87 (%41.05)
# Actual Value $10,440.30, Predicted value $6,040.87 (%42.14)
# Actual Value $10,477.90, Predicted value $6,038.45 (%42.37)
# Actual Value $10,504.80, Predicted value $6,038.31 (%42.52)
# Actual Value $10,651.20, Predicted value $6,036.66 (%43.32)
# Actual Value $10,817.00, Predicted value $6,034.25 (%44.22)
# Actual Value $11,069.65, Predicted value $6,032.19 (%45.51)
# Actual Value $11,016.90, Predicted value $6,032.28 (%45.25)
# Actual Value $10,576.85, Predicted value $6,034.23 (%42.95)
# Actual Value $10,545.50, Predicted value $6,038.25 (%42.74)
# Actual Value $10,382.70, Predicted value $6,037.76 (%41.85)
# Actual Value $10,458.35, Predicted value $6,038.12 (%42.27)
# Actual Value $10,242.65, Predicted value $6,041.76 (%41.01)
# Actual Value $10,360.15, Predicted value $6,040.85 (%41.69)
# Actual Value $10,114.75, Predicted value $6,042.21 (%40.26)
# Actual Value $10,113.70, Predicted value $6,046.78 (%40.21)
# Actual Value $10,325.15, Predicted value $6,043.75 (%41.47)
# Actual Value $10,458.65, Predicted value $6,038.91 (%42.26)
# Actual Value $10,565.30, Predicted value $6,037.28 (%42.86)
# Actual Value $10,617.80, Predicted value $6,035.84 (%43.15)
# Actual Value $10,679.65, Predicted value $6,035.23 (%43.49)
# Actual Value $10,716.55, Predicted value $6,034.98 (%43.69)
# Actual Value $10,682.70, Predicted value $6,034.31 (%43.51)
# Actual Value $10,513.85, Predicted value $6,036.56 (%42.58)
# Actual Value $10,736.15, Predicted value $6,033.27 (%43.80)
# Actual Value $10,768.35, Predicted value $6,034.86 (%43.96)
# Actual Value $10,808.05, Predicted value $6,034.13 (%44.17)
# Actual Value $10,741.10, Predicted value $6,033.97 (%43.82)
# Actual Value $10,589.10, Predicted value $6,034.32 (%43.01)
# Actual Value $10,749.75, Predicted value $6,034.81 (%43.86)
# Actual Value $11,023.20, Predicted value $6,033.36 (%45.27)
# Actual Value $10,957.10, Predicted value $6,032.59 (%44.94)
# Actual Value $11,167.30, Predicted value $6,031.90 (%45.99)
# Actual Value $11,244.70, Predicted value $6,031.02 (%46.37)
# Actual Value $11,470.70, Predicted value $6,030.87 (%47.42)
# Actual Value $11,385.05, Predicted value $6,030.91 (%47.03)
# Actual Value $11,582.75, Predicted value $6,030.70 (%47.93)
# Actual Value $11,676.80, Predicted value $6,030.46 (%48.36)
# Actual Value $11,536.90, Predicted value $6,030.47 (%47.73)
# Actual Value $11,369.90, Predicted value $6,030.85 (%46.96)
# Actual Value $11,234.35, Predicted value $6,031.05 (%46.32)
# Actual Value $10,977.55, Predicted value $6,030.67 (%45.06)
# Actual Value $10,599.25, Predicted value $6,031.92 (%43.09)
# Actual Value $10,234.65, Predicted value $6,032.60 (%41.06)
# Actual Value $10,453.05, Predicted value $6,037.80 (%42.24)
# Actual Value $10,124.90, Predicted value $6,040.31 (%40.34)
# Actual Value $10,380.45, Predicted value $6,035.36 (%41.86)
# Actual Value $10,598.40, Predicted value $6,037.63 (%43.03)
# Actual Value $10,616.70, Predicted value $6,035.81 (%43.15)
# Actual Value $10,526.75, Predicted value $6,034.09 (%42.68)
# Actual Value $10,858.70, Predicted value $6,034.73 (%44.42)
# Actual Value $10,601.15, Predicted value $6,031.63 (%43.10)
# Actual Value $10,791.55, Predicted value $6,031.83 (%44.11)
# Actual Value $10,951.70, Predicted value $6,032.01 (%44.92)
# Actual Value $10,779.80, Predicted value $6,033.12 (%44.03)
# Actual Value $10,672.25, Predicted value $6,034.29 (%43.46)
# Actual Value $10,821.60, Predicted value $6,033.08 (%44.25)
# Actual Value $10,905.20, Predicted value $6,032.58 (%44.68)
# Actual Value $10,849.80, Predicted value $6,031.87 (%44.41)
# Actual Value $10,830.95, Predicted value $6,030.57 (%44.32)
# Actual Value $11,069.40, Predicted value $6,031.43 (%45.51)
# Actual Value $10,746.05, Predicted value $6,031.10 (%43.88)
# Actual Value $10,789.85, Predicted value $6,032.00 (%44.10)
# Actual Value $10,792.50, Predicted value $6,030.60 (%44.12)
# Actual Value $11,058.20, Predicted value $6,032.09 (%45.45)
# Actual Value $11,343.25, Predicted value $6,030.70 (%46.83)
# Actual Value $11,521.05, Predicted value $6,030.56 (%47.66)
# Actual Value $11,570.00, Predicted value $6,030.32 (%47.88)
# Actual Value $11,598.00, Predicted value $6,030.24 (%48.01)
# Actual Value $11,596.70, Predicted value $6,030.39 (%48.00)
# Actual Value $11,752.80, Predicted value $6,030.40 (%48.69)
# Actual Value $11,641.80, Predicted value $6,030.34 (%48.20)
# Actual Value $11,724.75, Predicted value $6,030.38 (%48.57)
# Actual Value $11,301.80, Predicted value $6,030.38 (%46.64)
# Actual Value $11,257.10, Predicted value $6,030.47 (%46.43)
# Actual Value $11,657.05, Predicted value $6,030.20 (%48.27)
# Actual Value $11,945.90, Predicted value $6,030.17 (%49.52)
# Actual Value $11,843.75, Predicted value $6,030.22 (%49.09)
# Actual Value $11,914.05, Predicted value $6,030.21 (%49.39)
# Actual Value $11,831.75, Predicted value $6,030.19 (%49.03)
# Actual Value $11,841.55, Predicted value $6,030.20 (%49.08)
# Actual Value $11,946.75, Predicted value $6,030.22 (%49.52)
# Actual Value $11,582.90, Predicted value $6,030.18 (%47.94)
# Actual Value $11,596.90, Predicted value $6,030.19 (%48.00)
# Actual Value $11,252.15, Predicted value $6,030.18 (%46.41)
# Actual Value $10,980.00, Predicted value $6,030.21 (%45.08)
# Actual Value $11,032.45, Predicted value $6,030.22 (%45.34)
# Actual Value $11,029.40, Predicted value $6,031.10 (%45.32)
# Actual Value $10,741.35, Predicted value $6,030.27 (%43.86)
# Actual Value $10,948.30, Predicted value $6,030.14 (%44.92)
# Actual Value $10,847.90, Predicted value $6,030.51 (%44.41)
# Actual Value $10,982.80, Predicted value $6,030.54 (%45.09)
# Actual Value $10,704.80, Predicted value $6,030.21 (%43.67)
# Actual Value $11,571.20, Predicted value $6,030.13 (%47.89)
# Actual Value $11,314.00, Predicted value $6,030.13 (%46.70)
# Actual Value $11,234.55, Predicted value $6,030.14 (%46.33)
# Actual Value $11,586.35, Predicted value $6,030.13 (%47.95)
# Actual Value $11,582.60, Predicted value $6,030.13 (%47.94)
# Actual Value $11,877.45, Predicted value $6,030.13 (%49.23)
# Actual Value $12,012.05, Predicted value $6,030.13 (%49.80)
# Actual Value $11,872.10, Predicted value $6,030.13 (%49.21)
# Actual Value $11,968.40, Predicted value $6,030.13 (%49.62)
# Actual Value $12,151.15, Predicted value $6,030.13 (%50.37)
# Actual Value $12,018.40, Predicted value $6,030.13 (%49.83)
# Actual Value $11,971.80, Predicted value $6,030.13 (%49.63)
# Actual Value $12,259.70, Predicted value $6,030.13 (%50.81)
# Actual Value $12,126.55, Predicted value $6,030.13 (%50.27)
# Actual Value $12,282.20, Predicted value $6,030.14 (%50.90)
# Actual Value $12,215.90, Predicted value $6,030.14 (%50.64)
# Actual Value $12,355.50, Predicted value $6,030.13 (%51.19)
# Actual Value $12,180.35, Predicted value $6,030.13 (%50.49)
# Actual Value $12,035.80, Predicted value $6,030.13 (%49.90)
# Actual Value $12,137.95, Predicted value $6,030.13 (%50.32)
# Actual Value $12,174.65, Predicted value $6,030.13 (%50.47)
# Actual Value $12,080.85, Predicted value $6,030.14 (%50.09)
# Actual Value $11,633.30, Predicted value $6,030.17 (%48.16)
# Actual Value $11,269.00, Predicted value $6,030.13 (%46.49)
# Actual Value $9,590.15, Predicted value $6,030.13 (%37.12)
# Actual Value $8,263.45, Predicted value $6,030.13 (%27.03)
# Actual Value $8,641.45, Predicted value $6,030.13 (%30.22)
# Actual Value $8,253.80, Predicted value $6,033.20 (%26.90)
# Actual Value $9,111.90, Predicted value $6,030.45 (%33.82)
# Actual Value $8,992.80, Predicted value $6,038.01 (%32.86)
# Actual Value $9,313.90, Predicted value $6,030.17 (%35.26)
# Actual Value $9,859.90, Predicted value $6,030.17 (%38.84)
# Actual Value $9,199.05, Predicted value $6,030.81 (%34.44)
# Actual Value $9,142.75, Predicted value $6,030.15 (%34.04)
# Actual Value $9,106.25, Predicted value $6,030.21 (%33.78)
# Actual Value $9,490.10, Predicted value $6,030.64 (%36.45)
# Actual Value $10,029.10, Predicted value $6,030.13 (%39.87)
# Actual Value $9,902.00, Predicted value $6,030.13 (%39.10)
# Actual Value $10,091.65, Predicted value $6,030.13 (%40.25)
# Actual Value $10,288.90, Predicted value $6,030.13 (%41.39)
# Actual Value $10,551.70, Predicted value $6,030.19 (%42.85)
# Actual Value $10,813.45, Predicted value $6,030.15 (%44.23)
# Actual Value $10,739.95, Predicted value $6,030.15 (%43.85)
# Actual Value $11,215.45, Predicted value $6,030.13 (%46.23)
# Actual Value $11,102.15, Predicted value $6,030.13 (%45.69)
# Actual Value $11,200.15, Predicted value $6,030.13 (%46.16)
# Actual Value $11,300.45, Predicted value $6,030.16 (%46.64)
# Actual Value $11,312.20, Predicted value $6,030.13 (%46.69)
# Actual Value $11,559.25, Predicted value $6,030.13 (%47.83)
# Actual Value $11,527.45, Predicted value $6,030.13 (%47.69)
# Actual Value $11,449.25, Predicted value $6,030.13 (%47.33)
# Actual Value $11,516.10, Predicted value $6,030.20 (%47.64)
# Actual Value $10,805.55, Predicted value $6,030.13 (%44.19)
# Actual Value $11,416.95, Predicted value $6,030.21 (%47.18)
# Actual Value $11,834.60, Predicted value $6,030.17 (%49.05)
# Actual Value $11,680.35, Predicted value $6,030.13 (%48.37)
# Actual Value $11,896.45, Predicted value $6,030.13 (%49.31)
# Actual Value $11,670.80, Predicted value $6,030.13 (%48.33)
# Actual Value $12,120.30, Predicted value $6,030.13 (%50.25)
# Actual Value $12,690.80, Predicted value $6,030.13 (%52.48)
# Actual Value $12,771.70, Predicted value $6,030.13 (%52.79)
# Actual Value $12,987.00, Predicted value $6,030.13 (%53.57)
# Actual Value $13,133.90, Predicted value $6,030.13 (%54.09)
# Actual Value $13,478.30, Predicted value $6,030.13 (%55.26)
# Actual Value $13,740.70, Predicted value $6,030.13 (%56.11)
# Actual Value $13,749.25, Predicted value $6,030.13 (%56.14)
# Actual Value $13,981.75, Predicted value $6,030.13 (%56.87)
# Actual Value $14,146.25, Predicted value $6,030.13 (%57.37)
# Actual Value $14,188.90, Predicted value $6,030.13 (%57.50)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_SVR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_SVR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_SVR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_SVR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_SVR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 4522.14
# Mean squared error = 22111736.23
# Median absolute error = 4644.42
# Explain variance score = -0.04
# R2 score = -12.79

# %%
# Plotting the results

r = range(len(y_pred_SVR))

plt.title("Results Plot of SupportVectorRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_SVR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using KernalRidgeRegressor as model

model_KRR = KernelRidge(alpha=1.0).fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_KRR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_KRR.score(x_test, y_test))

pickle.dump(model_KRR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_KRR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 1.00000
#
#
# Score on testing data:
# ========================================
# 1.00000

# %%
y_pred_KRR = model_KRR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_KRR)):
    expl=((actual_data[i]-y_pred_KRR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_KRR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,673.25 (%0.00)
# Actual Value $8,592.20, Predicted value $8,592.20 (%0.00)
# Actual Value $8,774.65, Predicted value $8,774.65 (%0.00)
# Actual Value $8,952.50, Predicted value $8,952.50 (%0.00)
# Actual Value $8,742.55, Predicted value $8,742.55 (%-0.00)
# Actual Value $8,867.45, Predicted value $8,867.45 (%0.00)
# Actual Value $8,591.25, Predicted value $8,591.25 (%-0.00)
# Actual Value $8,709.55, Predicted value $8,709.55 (%-0.00)
# Actual Value $8,573.35, Predicted value $8,573.35 (%-0.00)
# Actual Value $8,699.40, Predicted value $8,699.40 (%0.00)
# Actual Value $8,615.25, Predicted value $8,615.25 (%0.00)
# Actual Value $8,484.95, Predicted value $8,484.95 (%-0.00)
# Actual Value $8,525.75, Predicted value $8,525.75 (%0.00)
# Actual Value $8,079.95, Predicted value $8,079.95 (%-0.00)
# Actual Value $7,965.50, Predicted value $7,965.50 (%-0.00)
# Actual Value $8,192.90, Predicted value $8,192.90 (%-0.00)
# Actual Value $8,246.85, Predicted value $8,246.85 (%0.00)
# Actual Value $8,153.60, Predicted value $8,153.60 (%0.00)
# Actual Value $7,979.10, Predicted value $7,979.10 (%-0.00)
# Actual Value $8,103.60, Predicted value $8,103.60 (%0.00)
# Actual Value $8,273.80, Predicted value $8,273.80 (%0.00)
# Actual Value $8,407.20, Predicted value $8,407.20 (%0.00)
# Actual Value $8,435.10, Predicted value $8,435.10 (%0.00)
# Actual Value $8,602.75, Predicted value $8,602.75 (%0.00)
# Actual Value $8,734.25, Predicted value $8,734.25 (%0.00)
# Actual Value $8,778.40, Predicted value $8,778.40 (%0.00)
# Actual Value $8,778.00, Predicted value $8,778.00 (%0.00)
# Actual Value $8,939.50, Predicted value $8,939.50 (%0.00)
# Actual Value $8,899.75, Predicted value $8,899.75 (%0.00)
# Actual Value $8,927.00, Predicted value $8,927.00 (%0.00)
# Actual Value $9,153.70, Predicted value $9,153.70 (%0.00)
# Actual Value $9,086.30, Predicted value $9,086.30 (%0.00)
# Actual Value $9,173.75, Predicted value $9,173.75 (%0.00)
# Actual Value $9,261.95, Predicted value $9,261.95 (%0.00)
# Actual Value $9,150.80, Predicted value $9,150.80 (%0.00)
# Actual Value $9,136.40, Predicted value $9,136.40 (%0.00)
# Actual Value $9,342.15, Predicted value $9,342.15 (%0.00)
# Actual Value $9,359.90, Predicted value $9,359.90 (%0.00)
# Actual Value $9,422.40, Predicted value $9,422.40 (%0.00)
# Actual Value $9,429.45, Predicted value $9,429.45 (%-0.00)
# Actual Value $9,509.75, Predicted value $9,509.75 (%0.00)
# Actual Value $9,616.10, Predicted value $9,616.10 (%0.00)
# Actual Value $9,647.25, Predicted value $9,647.25 (%0.00)
# Actual Value $9,578.05, Predicted value $9,578.05 (%0.00)
# Actual Value $9,630.00, Predicted value $9,630.00 (%0.00)
# Actual Value $9,504.10, Predicted value $9,504.10 (%0.00)
# Actual Value $9,674.55, Predicted value $9,674.55 (%0.00)
# Actual Value $9,891.70, Predicted value $9,891.70 (%0.00)
# Actual Value $9,873.30, Predicted value $9,873.30 (%0.00)
# Actual Value $10,020.55, Predicted value $10,020.55 (%-0.00)
# Actual Value $10,013.65, Predicted value $10,013.65 (%-0.00)
# Actual Value $9,820.25, Predicted value $9,820.25 (%-0.00)
# Actual Value $9,904.15, Predicted value $9,904.15 (%0.00)
# Actual Value $9,857.05, Predicted value $9,857.05 (%0.00)
# Actual Value $9,917.90, Predicted value $9,917.90 (%0.00)
# Actual Value $9,929.90, Predicted value $9,929.90 (%0.00)
# Actual Value $10,086.60, Predicted value $10,086.60 (%0.00)
# Actual Value $10,121.90, Predicted value $10,121.90 (%0.00)
# Actual Value $9,768.95, Predicted value $9,768.95 (%-0.00)
# Actual Value $9,888.70, Predicted value $9,888.70 (%0.00)
# Actual Value $10,096.40, Predicted value $10,096.40 (%0.00)
# Actual Value $10,146.55, Predicted value $10,146.55 (%-0.00)
# Actual Value $10,343.80, Predicted value $10,343.80 (%0.00)
# Actual Value $10,423.80, Predicted value $10,423.80 (%0.00)
# Actual Value $10,308.95, Predicted value $10,308.95 (%-0.00)
# Actual Value $10,214.75, Predicted value $10,214.75 (%0.00)
# Actual Value $10,348.75, Predicted value $10,348.75 (%0.00)
# Actual Value $10,226.55, Predicted value $10,226.55 (%-0.00)
# Actual Value $10,166.70, Predicted value $10,166.70 (%0.00)
# Actual Value $10,252.10, Predicted value $10,252.10 (%0.00)
# Actual Value $10,440.30, Predicted value $10,440.30 (%0.00)
# Actual Value $10,477.90, Predicted value $10,477.90 (%-0.00)
# Actual Value $10,504.80, Predicted value $10,504.80 (%0.00)
# Actual Value $10,651.20, Predicted value $10,651.20 (%0.00)
# Actual Value $10,817.00, Predicted value $10,817.00 (%0.00)
# Actual Value $11,069.65, Predicted value $11,069.65 (%0.00)
# Actual Value $11,016.90, Predicted value $11,016.90 (%0.00)
# Actual Value $10,576.85, Predicted value $10,576.85 (%0.00)
# Actual Value $10,545.50, Predicted value $10,545.50 (%-0.00)
# Actual Value $10,382.70, Predicted value $10,382.70 (%0.00)
# Actual Value $10,458.35, Predicted value $10,458.35 (%-0.00)
# Actual Value $10,242.65, Predicted value $10,242.65 (%0.00)
# Actual Value $10,360.15, Predicted value $10,360.15 (%-0.00)
# Actual Value $10,114.75, Predicted value $10,114.75 (%0.00)
# Actual Value $10,113.70, Predicted value $10,113.70 (%-0.00)
# Actual Value $10,325.15, Predicted value $10,325.15 (%0.00)
# Actual Value $10,458.65, Predicted value $10,458.65 (%0.00)
# Actual Value $10,565.30, Predicted value $10,565.30 (%0.00)
# Actual Value $10,617.80, Predicted value $10,617.80 (%0.00)
# Actual Value $10,679.65, Predicted value $10,679.65 (%-0.00)
# Actual Value $10,716.55, Predicted value $10,716.55 (%0.00)
# Actual Value $10,682.70, Predicted value $10,682.70 (%-0.00)
# Actual Value $10,513.85, Predicted value $10,513.85 (%0.00)
# Actual Value $10,736.15, Predicted value $10,736.15 (%0.00)
# Actual Value $10,768.35, Predicted value $10,768.35 (%0.00)
# Actual Value $10,808.05, Predicted value $10,808.05 (%-0.00)
# Actual Value $10,741.10, Predicted value $10,741.10 (%0.00)
# Actual Value $10,589.10, Predicted value $10,589.10 (%-0.00)
# Actual Value $10,749.75, Predicted value $10,749.75 (%0.00)
# Actual Value $11,023.20, Predicted value $11,023.20 (%-0.00)
# Actual Value $10,957.10, Predicted value $10,957.10 (%0.00)
# Actual Value $11,167.30, Predicted value $11,167.30 (%0.00)
# Actual Value $11,244.70, Predicted value $11,244.70 (%-0.00)
# Actual Value $11,470.70, Predicted value $11,470.70 (%0.00)
# Actual Value $11,385.05, Predicted value $11,385.05 (%0.00)
# Actual Value $11,582.75, Predicted value $11,582.75 (%0.00)
# Actual Value $11,676.80, Predicted value $11,676.80 (%0.00)
# Actual Value $11,536.90, Predicted value $11,536.90 (%0.00)
# Actual Value $11,369.90, Predicted value $11,369.90 (%0.00)
# Actual Value $11,234.35, Predicted value $11,234.35 (%-0.00)
# Actual Value $10,977.55, Predicted value $10,977.55 (%-0.00)
# Actual Value $10,599.25, Predicted value $10,599.25 (%-0.00)
# Actual Value $10,234.65, Predicted value $10,234.65 (%-0.00)
# Actual Value $10,453.05, Predicted value $10,453.05 (%-0.00)
# Actual Value $10,124.90, Predicted value $10,124.90 (%-0.00)
# Actual Value $10,380.45, Predicted value $10,380.45 (%0.00)
# Actual Value $10,598.40, Predicted value $10,598.40 (%0.00)
# Actual Value $10,616.70, Predicted value $10,616.70 (%0.00)
# Actual Value $10,526.75, Predicted value $10,526.75 (%-0.00)
# Actual Value $10,858.70, Predicted value $10,858.70 (%0.00)
# Actual Value $10,601.15, Predicted value $10,601.15 (%-0.00)
# Actual Value $10,791.55, Predicted value $10,791.55 (%0.00)
# Actual Value $10,951.70, Predicted value $10,951.70 (%0.00)
# Actual Value $10,779.80, Predicted value $10,779.80 (%0.00)
# Actual Value $10,672.25, Predicted value $10,672.25 (%-0.00)
# Actual Value $10,821.60, Predicted value $10,821.60 (%0.00)
# Actual Value $10,905.20, Predicted value $10,905.20 (%0.00)
# Actual Value $10,849.80, Predicted value $10,849.80 (%-0.00)
# Actual Value $10,830.95, Predicted value $10,830.95 (%0.00)
# Actual Value $11,069.40, Predicted value $11,069.40 (%0.00)
# Actual Value $10,746.05, Predicted value $10,746.05 (%-0.00)
# Actual Value $10,789.85, Predicted value $10,789.85 (%0.00)
# Actual Value $10,792.50, Predicted value $10,792.50 (%-0.00)
# Actual Value $11,058.20, Predicted value $11,058.20 (%0.00)
# Actual Value $11,343.25, Predicted value $11,343.25 (%0.00)
# Actual Value $11,521.05, Predicted value $11,521.05 (%0.00)
# Actual Value $11,570.00, Predicted value $11,570.00 (%0.00)
# Actual Value $11,598.00, Predicted value $11,598.00 (%-0.00)
# Actual Value $11,596.70, Predicted value $11,596.70 (%0.00)
# Actual Value $11,752.80, Predicted value $11,752.80 (%-0.00)
# Actual Value $11,641.80, Predicted value $11,641.80 (%0.00)
# Actual Value $11,724.75, Predicted value $11,724.75 (%0.00)
# Actual Value $11,301.80, Predicted value $11,301.80 (%-0.00)
# Actual Value $11,257.10, Predicted value $11,257.10 (%0.00)
# Actual Value $11,657.05, Predicted value $11,657.05 (%-0.00)
# Actual Value $11,945.90, Predicted value $11,945.90 (%0.00)
# Actual Value $11,843.75, Predicted value $11,843.75 (%-0.00)
# Actual Value $11,914.05, Predicted value $11,914.05 (%0.00)
# Actual Value $11,831.75, Predicted value $11,831.75 (%0.00)
# Actual Value $11,841.55, Predicted value $11,841.55 (%0.00)
# Actual Value $11,946.75, Predicted value $11,946.75 (%0.00)
# Actual Value $11,582.90, Predicted value $11,582.90 (%-0.00)
# Actual Value $11,596.90, Predicted value $11,596.90 (%0.00)
# Actual Value $11,252.15, Predicted value $11,252.15 (%-0.00)
# Actual Value $10,980.00, Predicted value $10,980.00 (%-0.00)
# Actual Value $11,032.45, Predicted value $11,032.45 (%0.00)
# Actual Value $11,029.40, Predicted value $11,029.40 (%0.00)
# Actual Value $10,741.35, Predicted value $10,741.35 (%-0.00)
# Actual Value $10,948.30, Predicted value $10,948.30 (%-0.00)
# Actual Value $10,847.90, Predicted value $10,847.90 (%0.00)
# Actual Value $10,982.80, Predicted value $10,982.80 (%-0.00)
# Actual Value $10,704.80, Predicted value $10,704.80 (%-0.00)
# Actual Value $11,571.20, Predicted value $11,571.20 (%-0.00)
# Actual Value $11,314.00, Predicted value $11,314.00 (%-0.00)
# Actual Value $11,234.55, Predicted value $11,234.55 (%0.00)
# Actual Value $11,586.35, Predicted value $11,586.35 (%0.00)
# Actual Value $11,582.60, Predicted value $11,582.60 (%-0.00)
# Actual Value $11,877.45, Predicted value $11,877.45 (%0.00)
# Actual Value $12,012.05, Predicted value $12,012.05 (%0.00)
# Actual Value $11,872.10, Predicted value $11,872.10 (%0.00)
# Actual Value $11,968.40, Predicted value $11,968.40 (%0.00)
# Actual Value $12,151.15, Predicted value $12,151.15 (%0.00)
# Actual Value $12,018.40, Predicted value $12,018.40 (%0.00)
# Actual Value $11,971.80, Predicted value $11,971.80 (%0.00)
# Actual Value $12,259.70, Predicted value $12,259.70 (%0.00)
# Actual Value $12,126.55, Predicted value $12,126.55 (%0.00)
# Actual Value $12,282.20, Predicted value $12,282.20 (%0.00)
# Actual Value $12,215.90, Predicted value $12,215.90 (%0.00)
# Actual Value $12,355.50, Predicted value $12,355.50 (%0.00)
# Actual Value $12,180.35, Predicted value $12,180.35 (%-0.00)
# Actual Value $12,035.80, Predicted value $12,035.80 (%-0.00)
# Actual Value $12,137.95, Predicted value $12,137.95 (%0.00)
# Actual Value $12,174.65, Predicted value $12,174.65 (%0.00)
# Actual Value $12,080.85, Predicted value $12,080.85 (%0.00)
# Actual Value $11,633.30, Predicted value $11,633.30 (%-0.00)
# Actual Value $11,269.00, Predicted value $11,269.00 (%0.00)
# Actual Value $9,590.15, Predicted value $9,590.15 (%-0.00)
# Actual Value $8,263.45, Predicted value $8,263.45 (%-0.00)
# Actual Value $8,641.45, Predicted value $8,641.45 (%0.00)
# Actual Value $8,253.80, Predicted value $8,253.80 (%-0.00)
# Actual Value $9,111.90, Predicted value $9,111.90 (%0.00)
# Actual Value $8,992.80, Predicted value $8,992.80 (%-0.00)
# Actual Value $9,313.90, Predicted value $9,313.90 (%0.00)
# Actual Value $9,859.90, Predicted value $9,859.90 (%0.00)
# Actual Value $9,199.05, Predicted value $9,199.05 (%-0.00)
# Actual Value $9,142.75, Predicted value $9,142.75 (%-0.00)
# Actual Value $9,106.25, Predicted value $9,106.25 (%0.00)
# Actual Value $9,490.10, Predicted value $9,490.10 (%0.00)
# Actual Value $10,029.10, Predicted value $10,029.10 (%-0.00)
# Actual Value $9,902.00, Predicted value $9,902.00 (%-0.00)
# Actual Value $10,091.65, Predicted value $10,091.65 (%0.00)
# Actual Value $10,288.90, Predicted value $10,288.90 (%-0.00)
# Actual Value $10,551.70, Predicted value $10,551.70 (%0.00)
# Actual Value $10,813.45, Predicted value $10,813.45 (%0.00)
# Actual Value $10,739.95, Predicted value $10,739.95 (%0.00)
# Actual Value $11,215.45, Predicted value $11,215.45 (%0.00)
# Actual Value $11,102.15, Predicted value $11,102.15 (%-0.00)
# Actual Value $11,200.15, Predicted value $11,200.15 (%0.00)
# Actual Value $11,300.45, Predicted value $11,300.45 (%0.00)
# Actual Value $11,312.20, Predicted value $11,312.20 (%0.00)
# Actual Value $11,559.25, Predicted value $11,559.25 (%0.00)
# Actual Value $11,527.45, Predicted value $11,527.45 (%-0.00)
# Actual Value $11,449.25, Predicted value $11,449.25 (%0.00)
# Actual Value $11,516.10, Predicted value $11,516.10 (%0.00)
# Actual Value $10,805.55, Predicted value $10,805.55 (%-0.00)
# Actual Value $11,416.95, Predicted value $11,416.95 (%0.00)
# Actual Value $11,834.60, Predicted value $11,834.60 (%0.00)
# Actual Value $11,680.35, Predicted value $11,680.35 (%-0.00)
# Actual Value $11,896.45, Predicted value $11,896.45 (%-0.00)
# Actual Value $11,670.80, Predicted value $11,670.80 (%-0.00)
# Actual Value $12,120.30, Predicted value $12,120.30 (%0.00)
# Actual Value $12,690.80, Predicted value $12,690.80 (%-0.00)
# Actual Value $12,771.70, Predicted value $12,771.70 (%-0.00)
# Actual Value $12,987.00, Predicted value $12,987.00 (%-0.00)
# Actual Value $13,133.90, Predicted value $13,133.90 (%0.00)
# Actual Value $13,478.30, Predicted value $13,478.30 (%0.00)
# Actual Value $13,740.70, Predicted value $13,740.70 (%0.00)
# Actual Value $13,749.25, Predicted value $13,749.25 (%0.00)
# Actual Value $13,981.75, Predicted value $13,981.75 (%0.00)
# Actual Value $14,146.25, Predicted value $14,146.25 (%0.00)
# Actual Value $14,188.90, Predicted value $14,188.90 (%0.00)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_KRR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_KRR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_KRR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_KRR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_KRR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 0.0
# Mean squared error = 0.0
# Median absolute error = 0.0
# Explain variance score = 1.0
# R2 score = 1.0

# %%
# Plotting the results

r = range(len(y_pred_KRR))

plt.title("Results Plot of KernalRidgeRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_KRR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using BayesianRidgeRegressor as model

model_BRR = BayesianRidge().fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_BRR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_BRR.score(x_test, y_test))

pickle.dump(model_BRR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_BRR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 1.00000
#
#
# Score on testing data:
# ========================================
# 1.00000

# %%
y_pred_BRR = model_BRR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_BRR)):
    expl=((actual_data[i]-y_pred_BRR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_BRR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,673.25 (%0.00)
# Actual Value $8,592.20, Predicted value $8,592.20 (%0.00)
# Actual Value $8,774.65, Predicted value $8,774.65 (%0.00)
# Actual Value $8,952.50, Predicted value $8,952.50 (%0.00)
# Actual Value $8,742.55, Predicted value $8,742.55 (%-0.00)
# Actual Value $8,867.45, Predicted value $8,867.45 (%0.00)
# Actual Value $8,591.25, Predicted value $8,591.25 (%0.00)
# Actual Value $8,709.55, Predicted value $8,709.55 (%0.00)
# Actual Value $8,573.35, Predicted value $8,573.35 (%0.00)
# Actual Value $8,699.40, Predicted value $8,699.40 (%0.00)
# Actual Value $8,615.25, Predicted value $8,615.25 (%0.00)
# Actual Value $8,484.95, Predicted value $8,484.95 (%0.00)
# Actual Value $8,525.75, Predicted value $8,525.75 (%-0.00)
# Actual Value $8,079.95, Predicted value $8,079.95 (%-0.00)
# Actual Value $7,965.50, Predicted value $7,965.50 (%0.00)
# Actual Value $8,192.90, Predicted value $8,192.90 (%0.00)
# Actual Value $8,246.85, Predicted value $8,246.85 (%-0.00)
# Actual Value $8,153.60, Predicted value $8,153.60 (%0.00)
# Actual Value $7,979.10, Predicted value $7,979.10 (%0.00)
# Actual Value $8,103.60, Predicted value $8,103.60 (%-0.00)
# Actual Value $8,273.80, Predicted value $8,273.80 (%0.00)
# Actual Value $8,407.20, Predicted value $8,407.20 (%0.00)
# Actual Value $8,435.10, Predicted value $8,435.10 (%0.00)
# Actual Value $8,602.75, Predicted value $8,602.75 (%-0.00)
# Actual Value $8,734.25, Predicted value $8,734.25 (%0.00)
# Actual Value $8,778.40, Predicted value $8,778.40 (%0.00)
# Actual Value $8,778.00, Predicted value $8,778.00 (%0.00)
# Actual Value $8,939.50, Predicted value $8,939.50 (%0.00)
# Actual Value $8,899.75, Predicted value $8,899.75 (%0.00)
# Actual Value $8,927.00, Predicted value $8,927.00 (%0.00)
# Actual Value $9,153.70, Predicted value $9,153.70 (%0.00)
# Actual Value $9,086.30, Predicted value $9,086.30 (%0.00)
# Actual Value $9,173.75, Predicted value $9,173.75 (%0.00)
# Actual Value $9,261.95, Predicted value $9,261.95 (%0.00)
# Actual Value $9,150.80, Predicted value $9,150.80 (%0.00)
# Actual Value $9,136.40, Predicted value $9,136.40 (%0.00)
# Actual Value $9,342.15, Predicted value $9,342.15 (%-0.00)
# Actual Value $9,359.90, Predicted value $9,359.90 (%0.00)
# Actual Value $9,422.40, Predicted value $9,422.40 (%0.00)
# Actual Value $9,429.45, Predicted value $9,429.45 (%0.00)
# Actual Value $9,509.75, Predicted value $9,509.75 (%-0.00)
# Actual Value $9,616.10, Predicted value $9,616.10 (%0.00)
# Actual Value $9,647.25, Predicted value $9,647.25 (%0.00)
# Actual Value $9,578.05, Predicted value $9,578.05 (%0.00)
# Actual Value $9,630.00, Predicted value $9,630.00 (%0.00)
# Actual Value $9,504.10, Predicted value $9,504.10 (%0.00)
# Actual Value $9,674.55, Predicted value $9,674.55 (%0.00)
# Actual Value $9,891.70, Predicted value $9,891.70 (%0.00)
# Actual Value $9,873.30, Predicted value $9,873.30 (%0.00)
# Actual Value $10,020.55, Predicted value $10,020.55 (%0.00)
# Actual Value $10,013.65, Predicted value $10,013.65 (%0.00)
# Actual Value $9,820.25, Predicted value $9,820.25 (%0.00)
# Actual Value $9,904.15, Predicted value $9,904.15 (%0.00)
# Actual Value $9,857.05, Predicted value $9,857.05 (%-0.00)
# Actual Value $9,917.90, Predicted value $9,917.90 (%-0.00)
# Actual Value $9,929.90, Predicted value $9,929.90 (%0.00)
# Actual Value $10,086.60, Predicted value $10,086.60 (%0.00)
# Actual Value $10,121.90, Predicted value $10,121.90 (%0.00)
# Actual Value $9,768.95, Predicted value $9,768.95 (%-0.00)
# Actual Value $9,888.70, Predicted value $9,888.70 (%0.00)
# Actual Value $10,096.40, Predicted value $10,096.40 (%0.00)
# Actual Value $10,146.55, Predicted value $10,146.55 (%0.00)
# Actual Value $10,343.80, Predicted value $10,343.80 (%0.00)
# Actual Value $10,423.80, Predicted value $10,423.80 (%0.00)
# Actual Value $10,308.95, Predicted value $10,308.95 (%0.00)
# Actual Value $10,214.75, Predicted value $10,214.75 (%0.00)
# Actual Value $10,348.75, Predicted value $10,348.75 (%0.00)
# Actual Value $10,226.55, Predicted value $10,226.55 (%0.00)
# Actual Value $10,166.70, Predicted value $10,166.70 (%-0.00)
# Actual Value $10,252.10, Predicted value $10,252.10 (%0.00)
# Actual Value $10,440.30, Predicted value $10,440.30 (%-0.00)
# Actual Value $10,477.90, Predicted value $10,477.90 (%0.00)
# Actual Value $10,504.80, Predicted value $10,504.80 (%0.00)
# Actual Value $10,651.20, Predicted value $10,651.20 (%0.00)
# Actual Value $10,817.00, Predicted value $10,817.00 (%0.00)
# Actual Value $11,069.65, Predicted value $11,069.65 (%0.00)
# Actual Value $11,016.90, Predicted value $11,016.90 (%0.00)
# Actual Value $10,576.85, Predicted value $10,576.85 (%-0.00)
# Actual Value $10,545.50, Predicted value $10,545.50 (%0.00)
# Actual Value $10,382.70, Predicted value $10,382.70 (%0.00)
# Actual Value $10,458.35, Predicted value $10,458.35 (%0.00)
# Actual Value $10,242.65, Predicted value $10,242.65 (%-0.00)
# Actual Value $10,360.15, Predicted value $10,360.15 (%0.00)
# Actual Value $10,114.75, Predicted value $10,114.75 (%0.00)
# Actual Value $10,113.70, Predicted value $10,113.70 (%0.00)
# Actual Value $10,325.15, Predicted value $10,325.15 (%0.00)
# Actual Value $10,458.65, Predicted value $10,458.65 (%0.00)
# Actual Value $10,565.30, Predicted value $10,565.30 (%0.00)
# Actual Value $10,617.80, Predicted value $10,617.80 (%0.00)
# Actual Value $10,679.65, Predicted value $10,679.65 (%0.00)
# Actual Value $10,716.55, Predicted value $10,716.55 (%0.00)
# Actual Value $10,682.70, Predicted value $10,682.70 (%0.00)
# Actual Value $10,513.85, Predicted value $10,513.85 (%-0.00)
# Actual Value $10,736.15, Predicted value $10,736.15 (%0.00)
# Actual Value $10,768.35, Predicted value $10,768.35 (%-0.00)
# Actual Value $10,808.05, Predicted value $10,808.05 (%0.00)
# Actual Value $10,741.10, Predicted value $10,741.10 (%0.00)
# Actual Value $10,589.10, Predicted value $10,589.10 (%0.00)
# Actual Value $10,749.75, Predicted value $10,749.75 (%0.00)
# Actual Value $11,023.20, Predicted value $11,023.20 (%0.00)
# Actual Value $10,957.10, Predicted value $10,957.10 (%0.00)
# Actual Value $11,167.30, Predicted value $11,167.30 (%0.00)
# Actual Value $11,244.70, Predicted value $11,244.70 (%0.00)
# Actual Value $11,470.70, Predicted value $11,470.70 (%0.00)
# Actual Value $11,385.05, Predicted value $11,385.05 (%0.00)
# Actual Value $11,582.75, Predicted value $11,582.75 (%0.00)
# Actual Value $11,676.80, Predicted value $11,676.80 (%0.00)
# Actual Value $11,536.90, Predicted value $11,536.90 (%0.00)
# Actual Value $11,369.90, Predicted value $11,369.90 (%-0.00)
# Actual Value $11,234.35, Predicted value $11,234.35 (%0.00)
# Actual Value $10,977.55, Predicted value $10,977.55 (%0.00)
# Actual Value $10,599.25, Predicted value $10,599.25 (%0.00)
# Actual Value $10,234.65, Predicted value $10,234.65 (%-0.00)
# Actual Value $10,453.05, Predicted value $10,453.05 (%0.00)
# Actual Value $10,124.90, Predicted value $10,124.90 (%0.00)
# Actual Value $10,380.45, Predicted value $10,380.45 (%0.00)
# Actual Value $10,598.40, Predicted value $10,598.40 (%0.00)
# Actual Value $10,616.70, Predicted value $10,616.70 (%-0.00)
# Actual Value $10,526.75, Predicted value $10,526.75 (%0.00)
# Actual Value $10,858.70, Predicted value $10,858.70 (%0.00)
# Actual Value $10,601.15, Predicted value $10,601.15 (%0.00)
# Actual Value $10,791.55, Predicted value $10,791.55 (%-0.00)
# Actual Value $10,951.70, Predicted value $10,951.70 (%0.00)
# Actual Value $10,779.80, Predicted value $10,779.80 (%-0.00)
# Actual Value $10,672.25, Predicted value $10,672.25 (%0.00)
# Actual Value $10,821.60, Predicted value $10,821.60 (%0.00)
# Actual Value $10,905.20, Predicted value $10,905.20 (%-0.00)
# Actual Value $10,849.80, Predicted value $10,849.80 (%0.00)
# Actual Value $10,830.95, Predicted value $10,830.95 (%-0.00)
# Actual Value $11,069.40, Predicted value $11,069.40 (%0.00)
# Actual Value $10,746.05, Predicted value $10,746.05 (%0.00)
# Actual Value $10,789.85, Predicted value $10,789.85 (%-0.00)
# Actual Value $10,792.50, Predicted value $10,792.50 (%0.00)
# Actual Value $11,058.20, Predicted value $11,058.20 (%0.00)
# Actual Value $11,343.25, Predicted value $11,343.25 (%0.00)
# Actual Value $11,521.05, Predicted value $11,521.05 (%0.00)
# Actual Value $11,570.00, Predicted value $11,570.00 (%-0.00)
# Actual Value $11,598.00, Predicted value $11,598.00 (%0.00)
# Actual Value $11,596.70, Predicted value $11,596.70 (%0.00)
# Actual Value $11,752.80, Predicted value $11,752.80 (%0.00)
# Actual Value $11,641.80, Predicted value $11,641.80 (%0.00)
# Actual Value $11,724.75, Predicted value $11,724.75 (%0.00)
# Actual Value $11,301.80, Predicted value $11,301.80 (%0.00)
# Actual Value $11,257.10, Predicted value $11,257.10 (%0.00)
# Actual Value $11,657.05, Predicted value $11,657.05 (%0.00)
# Actual Value $11,945.90, Predicted value $11,945.90 (%0.00)
# Actual Value $11,843.75, Predicted value $11,843.75 (%0.00)
# Actual Value $11,914.05, Predicted value $11,914.05 (%0.00)
# Actual Value $11,831.75, Predicted value $11,831.75 (%-0.00)
# Actual Value $11,841.55, Predicted value $11,841.55 (%0.00)
# Actual Value $11,946.75, Predicted value $11,946.75 (%0.00)
# Actual Value $11,582.90, Predicted value $11,582.90 (%-0.00)
# Actual Value $11,596.90, Predicted value $11,596.90 (%0.00)
# Actual Value $11,252.15, Predicted value $11,252.15 (%0.00)
# Actual Value $10,980.00, Predicted value $10,980.00 (%0.00)
# Actual Value $11,032.45, Predicted value $11,032.45 (%0.00)
# Actual Value $11,029.40, Predicted value $11,029.40 (%0.00)
# Actual Value $10,741.35, Predicted value $10,741.35 (%0.00)
# Actual Value $10,948.30, Predicted value $10,948.30 (%0.00)
# Actual Value $10,847.90, Predicted value $10,847.90 (%0.00)
# Actual Value $10,982.80, Predicted value $10,982.80 (%0.00)
# Actual Value $10,704.80, Predicted value $10,704.80 (%0.00)
# Actual Value $11,571.20, Predicted value $11,571.20 (%0.00)
# Actual Value $11,314.00, Predicted value $11,314.00 (%0.00)
# Actual Value $11,234.55, Predicted value $11,234.55 (%-0.00)
# Actual Value $11,586.35, Predicted value $11,586.35 (%0.00)
# Actual Value $11,582.60, Predicted value $11,582.60 (%0.00)
# Actual Value $11,877.45, Predicted value $11,877.45 (%0.00)
# Actual Value $12,012.05, Predicted value $12,012.05 (%0.00)
# Actual Value $11,872.10, Predicted value $11,872.10 (%0.00)
# Actual Value $11,968.40, Predicted value $11,968.40 (%0.00)
# Actual Value $12,151.15, Predicted value $12,151.15 (%0.00)
# Actual Value $12,018.40, Predicted value $12,018.40 (%0.00)
# Actual Value $11,971.80, Predicted value $11,971.80 (%0.00)
# Actual Value $12,259.70, Predicted value $12,259.70 (%0.00)
# Actual Value $12,126.55, Predicted value $12,126.55 (%0.00)
# Actual Value $12,282.20, Predicted value $12,282.20 (%0.00)
# Actual Value $12,215.90, Predicted value $12,215.90 (%-0.00)
# Actual Value $12,355.50, Predicted value $12,355.50 (%0.00)
# Actual Value $12,180.35, Predicted value $12,180.35 (%0.00)
# Actual Value $12,035.80, Predicted value $12,035.80 (%0.00)
# Actual Value $12,137.95, Predicted value $12,137.95 (%-0.00)
# Actual Value $12,174.65, Predicted value $12,174.65 (%0.00)
# Actual Value $12,080.85, Predicted value $12,080.85 (%0.00)
# Actual Value $11,633.30, Predicted value $11,633.30 (%-0.00)
# Actual Value $11,269.00, Predicted value $11,269.00 (%-0.00)
# Actual Value $9,590.15, Predicted value $9,590.15 (%-0.00)
# Actual Value $8,263.45, Predicted value $8,263.45 (%0.00)
# Actual Value $8,641.45, Predicted value $8,641.45 (%-0.00)
# Actual Value $8,253.80, Predicted value $8,253.80 (%-0.00)
# Actual Value $9,111.90, Predicted value $9,111.90 (%-0.00)
# Actual Value $8,992.80, Predicted value $8,992.80 (%0.00)
# Actual Value $9,313.90, Predicted value $9,313.90 (%-0.00)
# Actual Value $9,859.90, Predicted value $9,859.90 (%0.00)
# Actual Value $9,199.05, Predicted value $9,199.05 (%-0.00)
# Actual Value $9,142.75, Predicted value $9,142.75 (%0.00)
# Actual Value $9,106.25, Predicted value $9,106.25 (%-0.00)
# Actual Value $9,490.10, Predicted value $9,490.10 (%-0.00)
# Actual Value $10,029.10, Predicted value $10,029.10 (%0.00)
# Actual Value $9,902.00, Predicted value $9,902.00 (%0.00)
# Actual Value $10,091.65, Predicted value $10,091.65 (%0.00)
# Actual Value $10,288.90, Predicted value $10,288.90 (%0.00)
# Actual Value $10,551.70, Predicted value $10,551.70 (%-0.00)
# Actual Value $10,813.45, Predicted value $10,813.45 (%0.00)
# Actual Value $10,739.95, Predicted value $10,739.95 (%0.00)
# Actual Value $11,215.45, Predicted value $11,215.45 (%0.00)
# Actual Value $11,102.15, Predicted value $11,102.15 (%0.00)
# Actual Value $11,200.15, Predicted value $11,200.15 (%-0.00)
# Actual Value $11,300.45, Predicted value $11,300.45 (%0.00)
# Actual Value $11,312.20, Predicted value $11,312.20 (%0.00)
# Actual Value $11,559.25, Predicted value $11,559.25 (%0.00)
# Actual Value $11,527.45, Predicted value $11,527.45 (%0.00)
# Actual Value $11,449.25, Predicted value $11,449.25 (%-0.00)
# Actual Value $11,516.10, Predicted value $11,516.10 (%0.00)
# Actual Value $10,805.55, Predicted value $10,805.55 (%-0.00)
# Actual Value $11,416.95, Predicted value $11,416.95 (%0.00)
# Actual Value $11,834.60, Predicted value $11,834.60 (%0.00)
# Actual Value $11,680.35, Predicted value $11,680.35 (%0.00)
# Actual Value $11,896.45, Predicted value $11,896.45 (%0.00)
# Actual Value $11,670.80, Predicted value $11,670.80 (%0.00)
# Actual Value $12,120.30, Predicted value $12,120.30 (%-0.00)
# Actual Value $12,690.80, Predicted value $12,690.80 (%0.00)
# Actual Value $12,771.70, Predicted value $12,771.70 (%0.00)
# Actual Value $12,987.00, Predicted value $12,987.00 (%0.00)
# Actual Value $13,133.90, Predicted value $13,133.90 (%0.00)
# Actual Value $13,478.30, Predicted value $13,478.30 (%0.00)
# Actual Value $13,740.70, Predicted value $13,740.70 (%0.00)
# Actual Value $13,749.25, Predicted value $13,749.25 (%-0.00)
# Actual Value $13,981.75, Predicted value $13,981.75 (%0.00)
# Actual Value $14,146.25, Predicted value $14,146.25 (%0.00)
# Actual Value $14,188.90, Predicted value $14,188.90 (%0.00)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_BRR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_BRR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_BRR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_BRR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_BRR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 0.0
# Mean squared error = 0.0
# Median absolute error = 0.0
# Explain variance score = 1.0
# R2 score = 1.0

# %%
# Plotting the results

r = range(len(y_pred_KRR))

plt.title("Results Plot of BayesianRidgeRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_BRR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using LassoRegressor as model

model_LSS = Lasso(alpha = 0).fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_LSS.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_LSS.score(x_test, y_test))

pickle.dump(model_LSS, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_LSS.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.99996
#
#
# Score on testing data:
# ========================================
# 0.99989
# <ipython-input-82-8892823a28ff>:3: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model_LSS = Lasso(alpha = 0).fit(x_train, y_train)
# C:\Users\amolk\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(

# %%
y_pred_LSS = model_LSS.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_LSS)):
    expl=((actual_data[i]-y_pred_LSS[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_LSS[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,668.14 (%0.06)
# Actual Value $8,592.20, Predicted value $8,592.98 (%-0.01)
# Actual Value $8,774.65, Predicted value $8,771.86 (%0.03)
# Actual Value $8,952.50, Predicted value $8,950.47 (%0.02)
# Actual Value $8,742.55, Predicted value $8,742.08 (%0.01)
# Actual Value $8,867.45, Predicted value $8,866.52 (%0.01)
# Actual Value $8,591.25, Predicted value $8,594.84 (%-0.04)
# Actual Value $8,709.55, Predicted value $8,716.84 (%-0.08)
# Actual Value $8,573.35, Predicted value $8,576.00 (%-0.03)
# Actual Value $8,699.40, Predicted value $8,693.36 (%0.07)
# Actual Value $8,615.25, Predicted value $8,613.92 (%0.02)
# Actual Value $8,484.95, Predicted value $8,491.73 (%-0.08)
# Actual Value $8,525.75, Predicted value $8,487.38 (%0.45)
# Actual Value $8,079.95, Predicted value $8,086.74 (%-0.08)
# Actual Value $7,965.50, Predicted value $7,966.82 (%-0.02)
# Actual Value $8,192.90, Predicted value $8,195.08 (%-0.03)
# Actual Value $8,246.85, Predicted value $8,238.03 (%0.11)
# Actual Value $8,153.60, Predicted value $8,153.11 (%0.01)
# Actual Value $7,979.10, Predicted value $7,981.85 (%-0.03)
# Actual Value $8,103.60, Predicted value $8,096.10 (%0.09)
# Actual Value $8,273.80, Predicted value $8,273.08 (%0.01)
# Actual Value $8,407.20, Predicted value $8,402.22 (%0.06)
# Actual Value $8,435.10, Predicted value $8,429.61 (%0.07)
# Actual Value $8,602.75, Predicted value $8,595.41 (%0.09)
# Actual Value $8,734.25, Predicted value $8,728.79 (%0.06)
# Actual Value $8,778.40, Predicted value $8,779.73 (%-0.02)
# Actual Value $8,778.00, Predicted value $8,773.69 (%0.05)
# Actual Value $8,939.50, Predicted value $8,935.97 (%0.04)
# Actual Value $8,899.75, Predicted value $8,902.53 (%-0.03)
# Actual Value $8,927.00, Predicted value $8,929.62 (%-0.03)
# Actual Value $9,153.70, Predicted value $9,148.31 (%0.06)
# Actual Value $9,086.30, Predicted value $9,083.42 (%0.03)
# Actual Value $9,173.75, Predicted value $9,166.52 (%0.08)
# Actual Value $9,261.95, Predicted value $9,261.62 (%0.00)
# Actual Value $9,150.80, Predicted value $9,154.24 (%-0.04)
# Actual Value $9,136.40, Predicted value $9,138.54 (%-0.02)
# Actual Value $9,342.15, Predicted value $9,335.46 (%0.07)
# Actual Value $9,359.90, Predicted value $9,353.31 (%0.07)
# Actual Value $9,422.40, Predicted value $9,415.34 (%0.07)
# Actual Value $9,429.45, Predicted value $9,434.42 (%-0.05)
# Actual Value $9,509.75, Predicted value $9,498.65 (%0.12)
# Actual Value $9,616.10, Predicted value $9,617.52 (%-0.01)
# Actual Value $9,647.25, Predicted value $9,651.06 (%-0.04)
# Actual Value $9,578.05, Predicted value $9,581.43 (%-0.04)
# Actual Value $9,630.00, Predicted value $9,634.12 (%-0.04)
# Actual Value $9,504.10, Predicted value $9,504.42 (%-0.00)
# Actual Value $9,674.55, Predicted value $9,673.44 (%0.01)
# Actual Value $9,891.70, Predicted value $9,888.44 (%0.03)
# Actual Value $9,873.30, Predicted value $9,867.79 (%0.06)
# Actual Value $10,020.55, Predicted value $10,024.34 (%-0.04)
# Actual Value $10,013.65, Predicted value $10,021.99 (%-0.08)
# Actual Value $9,820.25, Predicted value $9,828.91 (%-0.09)
# Actual Value $9,904.15, Predicted value $9,905.27 (%-0.01)
# Actual Value $9,857.05, Predicted value $9,847.94 (%0.09)
# Actual Value $9,917.90, Predicted value $9,906.83 (%0.11)
# Actual Value $9,929.90, Predicted value $9,928.80 (%0.01)
# Actual Value $10,086.60, Predicted value $10,086.41 (%0.00)
# Actual Value $10,121.90, Predicted value $10,125.64 (%-0.04)
# Actual Value $9,768.95, Predicted value $9,768.62 (%0.00)
# Actual Value $9,888.70, Predicted value $9,890.66 (%-0.02)
# Actual Value $10,096.40, Predicted value $10,095.85 (%0.01)
# Actual Value $10,146.55, Predicted value $10,157.19 (%-0.10)
# Actual Value $10,343.80, Predicted value $10,338.99 (%0.05)
# Actual Value $10,423.80, Predicted value $10,421.44 (%0.02)
# Actual Value $10,308.95, Predicted value $10,311.24 (%-0.02)
# Actual Value $10,214.75, Predicted value $10,209.68 (%0.05)
# Actual Value $10,348.75, Predicted value $10,345.12 (%0.04)
# Actual Value $10,226.55, Predicted value $10,232.57 (%-0.06)
# Actual Value $10,166.70, Predicted value $10,157.25 (%0.09)
# Actual Value $10,252.10, Predicted value $10,254.68 (%-0.03)
# Actual Value $10,440.30, Predicted value $10,420.74 (%0.19)
# Actual Value $10,477.90, Predicted value $10,484.69 (%-0.06)
# Actual Value $10,504.80, Predicted value $10,499.97 (%0.05)
# Actual Value $10,651.20, Predicted value $10,650.37 (%0.01)
# Actual Value $10,817.00, Predicted value $10,815.95 (%0.01)
# Actual Value $11,069.65, Predicted value $11,069.42 (%0.00)
# Actual Value $11,016.90, Predicted value $11,015.47 (%0.01)
# Actual Value $10,576.85, Predicted value $10,559.32 (%0.17)
# Actual Value $10,545.50, Predicted value $10,550.86 (%-0.05)
# Actual Value $10,382.70, Predicted value $10,381.67 (%0.01)
# Actual Value $10,458.35, Predicted value $10,475.77 (%-0.17)
# Actual Value $10,242.65, Predicted value $10,238.68 (%0.04)
# Actual Value $10,360.15, Predicted value $10,366.96 (%-0.07)
# Actual Value $10,114.75, Predicted value $10,113.65 (%0.01)
# Actual Value $10,113.70, Predicted value $10,121.44 (%-0.08)
# Actual Value $10,325.15, Predicted value $10,320.98 (%0.04)
# Actual Value $10,458.65, Predicted value $10,455.81 (%0.03)
# Actual Value $10,565.30, Predicted value $10,558.58 (%0.06)
# Actual Value $10,617.80, Predicted value $10,615.02 (%0.03)
# Actual Value $10,679.65, Predicted value $10,690.32 (%-0.10)
# Actual Value $10,716.55, Predicted value $10,714.51 (%0.02)
# Actual Value $10,682.70, Predicted value $10,702.64 (%-0.19)
# Actual Value $10,513.85, Predicted value $10,508.54 (%0.05)
# Actual Value $10,736.15, Predicted value $10,736.90 (%-0.01)
# Actual Value $10,768.35, Predicted value $10,756.07 (%0.11)
# Actual Value $10,808.05, Predicted value $10,814.15 (%-0.06)
# Actual Value $10,741.10, Predicted value $10,741.18 (%-0.00)
# Actual Value $10,589.10, Predicted value $10,599.67 (%-0.10)
# Actual Value $10,749.75, Predicted value $10,751.88 (%-0.02)
# Actual Value $11,023.20, Predicted value $11,027.01 (%-0.03)
# Actual Value $10,957.10, Predicted value $10,958.14 (%-0.01)
# Actual Value $11,167.30, Predicted value $11,166.43 (%0.01)
# Actual Value $11,244.70, Predicted value $11,258.13 (%-0.12)
# Actual Value $11,470.70, Predicted value $11,471.89 (%-0.01)
# Actual Value $11,385.05, Predicted value $11,382.98 (%0.02)
# Actual Value $11,582.75, Predicted value $11,585.41 (%-0.02)
# Actual Value $11,676.80, Predicted value $11,681.92 (%-0.04)
# Actual Value $11,536.90, Predicted value $11,534.98 (%0.02)
# Actual Value $11,369.90, Predicted value $11,367.94 (%0.02)
# Actual Value $11,234.35, Predicted value $11,245.49 (%-0.10)
# Actual Value $10,977.55, Predicted value $10,982.00 (%-0.04)
# Actual Value $10,599.25, Predicted value $10,606.51 (%-0.07)
# Actual Value $10,234.65, Predicted value $10,234.58 (%0.00)
# Actual Value $10,453.05, Predicted value $10,479.75 (%-0.26)
# Actual Value $10,124.90, Predicted value $10,132.77 (%-0.08)
# Actual Value $10,380.45, Predicted value $10,374.86 (%0.05)
# Actual Value $10,598.40, Predicted value $10,598.93 (%-0.00)
# Actual Value $10,616.70, Predicted value $10,604.01 (%0.12)
# Actual Value $10,526.75, Predicted value $10,541.96 (%-0.14)
# Actual Value $10,858.70, Predicted value $10,852.64 (%0.06)
# Actual Value $10,601.15, Predicted value $10,611.49 (%-0.10)
# Actual Value $10,791.55, Predicted value $10,767.16 (%0.23)
# Actual Value $10,951.70, Predicted value $10,951.11 (%0.01)
# Actual Value $10,779.80, Predicted value $10,762.86 (%0.16)
# Actual Value $10,672.25, Predicted value $10,685.56 (%-0.12)
# Actual Value $10,821.60, Predicted value $10,819.39 (%0.02)
# Actual Value $10,905.20, Predicted value $10,894.08 (%0.10)
# Actual Value $10,849.80, Predicted value $10,853.96 (%-0.04)
# Actual Value $10,830.95, Predicted value $10,816.16 (%0.14)
# Actual Value $11,069.40, Predicted value $11,069.84 (%-0.00)
# Actual Value $10,746.05, Predicted value $10,751.25 (%-0.05)
# Actual Value $10,789.85, Predicted value $10,773.36 (%0.15)
# Actual Value $10,792.50, Predicted value $10,802.99 (%-0.10)
# Actual Value $11,058.20, Predicted value $11,057.84 (%0.00)
# Actual Value $11,343.25, Predicted value $11,343.18 (%0.00)
# Actual Value $11,521.05, Predicted value $11,523.17 (%-0.02)
# Actual Value $11,570.00, Predicted value $11,549.54 (%0.18)
# Actual Value $11,598.00, Predicted value $11,609.36 (%-0.10)
# Actual Value $11,596.70, Predicted value $11,600.62 (%-0.03)
# Actual Value $11,752.80, Predicted value $11,760.10 (%-0.06)
# Actual Value $11,641.80, Predicted value $11,643.86 (%-0.02)
# Actual Value $11,724.75, Predicted value $11,728.59 (%-0.03)
# Actual Value $11,301.80, Predicted value $11,312.19 (%-0.09)
# Actual Value $11,257.10, Predicted value $11,247.56 (%0.08)
# Actual Value $11,657.05, Predicted value $11,697.51 (%-0.35)
# Actual Value $11,945.90, Predicted value $11,938.71 (%0.06)
# Actual Value $11,843.75, Predicted value $11,856.96 (%-0.11)
# Actual Value $11,914.05, Predicted value $11,914.02 (%0.00)
# Actual Value $11,831.75, Predicted value $11,814.16 (%0.15)
# Actual Value $11,841.55, Predicted value $11,832.36 (%0.08)
# Actual Value $11,946.75, Predicted value $11,940.41 (%0.05)
# Actual Value $11,582.90, Predicted value $11,581.93 (%0.01)
# Actual Value $11,596.90, Predicted value $11,601.92 (%-0.04)
# Actual Value $11,252.15, Predicted value $11,259.45 (%-0.06)
# Actual Value $10,980.00, Predicted value $10,983.39 (%-0.03)
# Actual Value $11,032.45, Predicted value $11,022.89 (%0.09)
# Actual Value $11,029.40, Predicted value $11,028.76 (%0.01)
# Actual Value $10,741.35, Predicted value $10,756.89 (%-0.14)
# Actual Value $10,948.30, Predicted value $10,962.09 (%-0.13)
# Actual Value $10,847.90, Predicted value $10,847.10 (%0.01)
# Actual Value $10,982.80, Predicted value $10,991.02 (%-0.07)
# Actual Value $10,704.80, Predicted value $10,718.13 (%-0.12)
# Actual Value $11,571.20, Predicted value $11,575.70 (%-0.04)
# Actual Value $11,314.00, Predicted value $11,316.50 (%-0.02)
# Actual Value $11,234.55, Predicted value $11,225.21 (%0.08)
# Actual Value $11,586.35, Predicted value $11,579.24 (%0.06)
# Actual Value $11,582.60, Predicted value $11,591.89 (%-0.08)
# Actual Value $11,877.45, Predicted value $11,868.67 (%0.07)
# Actual Value $12,012.05, Predicted value $12,007.42 (%0.04)
# Actual Value $11,872.10, Predicted value $11,872.72 (%-0.01)
# Actual Value $11,968.40, Predicted value $11,971.52 (%-0.03)
# Actual Value $12,151.15, Predicted value $12,142.49 (%0.07)
# Actual Value $12,018.40, Predicted value $12,012.72 (%0.05)
# Actual Value $11,971.80, Predicted value $11,960.64 (%0.09)
# Actual Value $12,259.70, Predicted value $12,258.58 (%0.01)
# Actual Value $12,126.55, Predicted value $12,131.25 (%-0.04)
# Actual Value $12,282.20, Predicted value $12,279.92 (%0.02)
# Actual Value $12,215.90, Predicted value $12,190.54 (%0.21)
# Actual Value $12,355.50, Predicted value $12,352.59 (%0.02)
# Actual Value $12,180.35, Predicted value $12,185.92 (%-0.05)
# Actual Value $12,035.80, Predicted value $12,046.66 (%-0.09)
# Actual Value $12,137.95, Predicted value $12,094.96 (%0.35)
# Actual Value $12,174.65, Predicted value $12,165.37 (%0.08)
# Actual Value $12,080.85, Predicted value $12,073.10 (%0.06)
# Actual Value $11,633.30, Predicted value $11,632.66 (%0.01)
# Actual Value $11,269.00, Predicted value $11,254.62 (%0.13)
# Actual Value $9,590.15, Predicted value $9,623.25 (%-0.35)
# Actual Value $8,263.45, Predicted value $8,359.78 (%-1.17)
# Actual Value $8,641.45, Predicted value $8,595.34 (%0.53)
# Actual Value $8,253.80, Predicted value $8,274.14 (%-0.25)
# Actual Value $9,111.90, Predicted value $9,082.98 (%0.32)
# Actual Value $8,992.80, Predicted value $8,996.32 (%-0.04)
# Actual Value $9,313.90, Predicted value $9,283.40 (%0.33)
# Actual Value $9,859.90, Predicted value $9,857.44 (%0.02)
# Actual Value $9,199.05, Predicted value $9,198.23 (%0.01)
# Actual Value $9,142.75, Predicted value $9,161.00 (%-0.20)
# Actual Value $9,106.25, Predicted value $9,079.37 (%0.30)
# Actual Value $9,490.10, Predicted value $9,480.75 (%0.10)
# Actual Value $10,029.10, Predicted value $10,037.83 (%-0.09)
# Actual Value $9,902.00, Predicted value $9,929.61 (%-0.28)
# Actual Value $10,091.65, Predicted value $10,090.50 (%0.01)
# Actual Value $10,288.90, Predicted value $10,312.00 (%-0.22)
# Actual Value $10,551.70, Predicted value $10,540.95 (%0.10)
# Actual Value $10,813.45, Predicted value $10,810.59 (%0.03)
# Actual Value $10,739.95, Predicted value $10,737.64 (%0.02)
# Actual Value $11,215.45, Predicted value $11,215.11 (%0.00)
# Actual Value $11,102.15, Predicted value $11,121.77 (%-0.18)
# Actual Value $11,200.15, Predicted value $11,181.60 (%0.17)
# Actual Value $11,300.45, Predicted value $11,303.04 (%-0.02)
# Actual Value $11,312.20, Predicted value $11,305.57 (%0.06)
# Actual Value $11,559.25, Predicted value $11,559.62 (%-0.00)
# Actual Value $11,527.45, Predicted value $11,530.73 (%-0.03)
# Actual Value $11,449.25, Predicted value $11,433.92 (%0.13)
# Actual Value $11,516.10, Predicted value $11,520.42 (%-0.04)
# Actual Value $10,805.55, Predicted value $10,821.43 (%-0.15)
# Actual Value $11,416.95, Predicted value $11,410.52 (%0.06)
# Actual Value $11,834.60, Predicted value $11,837.23 (%-0.02)
# Actual Value $11,680.35, Predicted value $11,700.94 (%-0.18)
# Actual Value $11,896.45, Predicted value $11,903.02 (%-0.06)
# Actual Value $11,670.80, Predicted value $11,672.51 (%-0.01)
# Actual Value $12,120.30, Predicted value $12,105.90 (%0.12)
# Actual Value $12,690.80, Predicted value $12,694.37 (%-0.03)
# Actual Value $12,771.70, Predicted value $12,786.91 (%-0.12)
# Actual Value $12,987.00, Predicted value $12,995.47 (%-0.07)
# Actual Value $13,133.90, Predicted value $13,132.69 (%0.01)
# Actual Value $13,478.30, Predicted value $13,481.94 (%-0.03)
# Actual Value $13,740.70, Predicted value $13,732.67 (%0.06)
# Actual Value $13,749.25, Predicted value $13,693.96 (%0.40)
# Actual Value $13,981.75, Predicted value $13,985.03 (%-0.02)
# Actual Value $14,146.25, Predicted value $14,142.72 (%0.02)
# Actual Value $14,188.90, Predicted value $14,188.44 (%0.00)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_LSS), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_LSS), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_LSS), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_LSS), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_LSS), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 8.01
# Mean squared error = 170.81
# Median absolute error = 5.07
# Explain variance score = 1.0
# R2 score = 1.0

# %%
y_pred_LSS
# Out:
# array([ 8668.13562514,  8592.98041636,  8771.86320766,  8950.46579179,
#         8742.0773488 ,  8866.52341871,  8594.84094867,  8716.84150888,
#         8576.00212686,  8693.35778959,  8613.91632224,  8491.73365399,
#         8487.38399291,  8086.74257836,  7966.81568365,  8195.08181734,
#         8238.03374793,  8153.11292785,  7981.8529491 ,  8096.09816187,
#         8273.08337418,  8402.22364622,  8429.60511856,  8595.41011147,
#         8728.78691047,  8779.73235096,  8773.68994267,  8935.96650474,
#         8902.53095977,  8929.61577909,  9148.30967443,  9083.41501149,
#         9166.51827244,  9261.62476516,  9154.24045638,  9138.53567668,
#         9335.46038496,  9353.30915651,  9415.34066355,  9434.41633232,
#         9498.65482442,  9617.52433807,  9651.05519682,  9581.42520435,
#         9634.11988723,  9504.41733583,  9673.43758797,  9888.43922233,
#         9867.79058289, 10024.3413799 , 10021.99207684,  9828.90552222,
#         9905.27253143,  9847.93971703,  9906.834186  ,  9928.80141349,
#        10086.4054382 , 10125.63633341,  9768.61771405,  9890.6583696 ,
#        10095.85248786, 10157.18619049, 10338.99436845, 10421.4372117 ,
#        10311.23672946, 10209.67838334, 10345.11621646, 10232.57292154,
#        10157.25175658, 10254.67677897, 10420.74321348, 10484.68706278,
#        10499.96798165, 10650.36616093, 10815.95393967, 11069.42274565,
#        11015.46585813, 10559.32287449, 10550.86434501, 10381.67436133,
#        10475.76540662, 10238.68238052, 10366.96432018, 10113.65275796,
#        10121.44353035, 10320.98068841, 10455.81013401, 10558.5826784 ,
#        10615.02413398, 10690.31566162, 10714.51317954, 10702.64469356,
#        10508.53594773, 10736.90223871, 10756.07094966, 10814.14770174,
#        10741.18221381, 10599.66837458, 10751.88264618, 11027.00618811,
#        10958.1423729 , 11166.42565127, 11258.13397267, 11471.89306206,
#        11382.97826744, 11585.41302795, 11681.9150795 , 11534.98412962,
#        11367.93785758, 11245.48580277, 10982.00297726, 10606.51054126,
#        10234.57856425, 10479.74710109, 10132.76797408, 10374.85626346,
#        10598.92749235, 10604.01093531, 10541.96492977, 10852.64409596,
#        10611.49207924, 10767.15735258, 10951.11204574, 10762.85758377,
#        10685.56080745, 10819.3873048 , 10894.07606214, 10853.9561715 ,
#        10816.15592865, 11069.84106778, 10751.24564169, 10773.35900343,
#        10802.99014198, 11057.84280504, 11343.18056625, 11523.16627638,
#        11549.53503271, 11609.3569884 , 11600.622006  , 11760.10269281,
#        11643.85554211, 11728.58795308, 11312.18541672, 11247.55723418,
#        11697.51291486, 11938.70851763, 11856.96098066, 11914.02011853,
#        11814.16020904, 11832.36274645, 11940.41125953, 11581.93393941,
#        11601.9216871 , 11259.44994408, 10983.38649152, 11022.88610099,
#        11028.76342814, 10756.89129675, 10962.09070915, 10847.10179139,
#        10991.02096769, 10718.12547989, 11575.69992009, 11316.50268705,
#        11225.20712232, 11579.24365097, 11591.88955585, 11868.66858293,
#        12007.41858032, 11872.71567521, 11971.52316297, 12142.48956257,
#        12012.71774158, 11960.63872167, 12258.57779935, 12131.24699771,
#        12279.92307828, 12190.54198985, 12352.58601939, 12185.91804026,
#        12046.65925487, 12094.95720929, 12165.37129161, 12073.09914382,
#        11632.66213893, 11254.62097799,  9623.25253046,  8359.78289793,
#         8595.34232983,  8274.13909653,  9082.98323762,  8996.3191552 ,
#         9283.40342884,  9857.44492834,  9198.23176548,  9161.0011221 ,
#         9079.37449873,  9480.75052717, 10037.82683953,  9929.60868587,
#        10090.50109327, 10312.00401363, 10540.94711497, 10810.58860972,
#        10737.64194168, 11215.1148866 , 11121.76749648, 11181.60155664,
#        11303.03702221, 11305.5744443 , 11559.62482798, 11530.7305976 ,
#        11433.92426523, 11520.42184497, 10821.42603482, 11410.51778298,
#        11837.23336064, 11700.93618607, 11903.01858577, 11672.50827638,
#        12105.90294357, 12694.37453014, 12786.90696063, 12995.46594789,
#        13132.68855817, 13481.94483462, 13732.66967371, 13693.95757259,
#        13985.02614031, 14142.72204382, 14188.436113  ])

# %%
# Plotting the results

r = range(len(y_pred_LSS))

plt.title("Results Plot of LassoRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_LSS, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using DecisionTreeRegressor as model

model_DTR = DecisionTreeRegressor(random_state = 10).fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_DTR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_DTR.score(x_test, y_test))

pickle.dump(model_DTR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_DTR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 1.00000
#
#
# Score on testing data:
# ========================================
# -1.64055

# %%
y_pred_DTR = model_DTR.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_DTR)):
    expl=((actual_data[i]-y_pred_DTR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_DTR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,666.30 (%0.08)
# Actual Value $8,592.20, Predicted value $8,592.15 (%0.00)
# Actual Value $8,774.65, Predicted value $8,778.30 (%-0.04)
# Actual Value $8,952.50, Predicted value $8,952.35 (%0.00)
# Actual Value $8,742.55, Predicted value $8,776.00 (%-0.38)
# Actual Value $8,867.45, Predicted value $8,895.30 (%-0.31)
# Actual Value $8,591.25, Predicted value $8,592.15 (%-0.01)
# Actual Value $8,709.55, Predicted value $8,711.55 (%-0.02)
# Actual Value $8,573.35, Predicted value $8,551.10 (%0.26)
# Actual Value $8,699.40, Predicted value $8,711.55 (%-0.14)
# Actual Value $8,615.25, Predicted value $8,592.15 (%0.27)
# Actual Value $8,484.95, Predicted value $8,510.10 (%-0.30)
# Actual Value $8,525.75, Predicted value $8,494.15 (%0.37)
# Actual Value $8,079.95, Predicted value $8,057.30 (%0.28)
# Actual Value $7,965.50, Predicted value $7,965.35 (%0.00)
# Actual Value $8,192.90, Predicted value $8,218.95 (%-0.32)
# Actual Value $8,246.85, Predicted value $8,234.60 (%0.15)
# Actual Value $8,153.60, Predicted value $8,169.20 (%-0.19)
# Actual Value $7,979.10, Predicted value $7,965.35 (%0.17)
# Actual Value $8,103.60, Predicted value $8,057.30 (%0.57)
# Actual Value $8,273.80, Predicted value $8,270.45 (%0.04)
# Actual Value $8,407.20, Predicted value $8,398.00 (%0.11)
# Actual Value $8,435.10, Predicted value $8,421.80 (%0.16)
# Actual Value $8,602.75, Predicted value $8,589.80 (%0.15)
# Actual Value $8,734.25, Predicted value $8,711.70 (%0.26)
# Actual Value $8,778.40, Predicted value $8,778.30 (%0.00)
# Actual Value $8,778.00, Predicted value $8,776.00 (%0.02)
# Actual Value $8,939.50, Predicted value $8,952.35 (%-0.14)
# Actual Value $8,899.75, Predicted value $8,952.35 (%-0.59)
# Actual Value $8,927.00, Predicted value $8,952.35 (%-0.28)
# Actual Value $9,153.70, Predicted value $8,937.75 (%2.36)
# Actual Value $9,086.30, Predicted value $8,937.75 (%1.63)
# Actual Value $9,173.75, Predicted value $8,937.75 (%2.57)
# Actual Value $9,261.95, Predicted value $8,937.75 (%3.50)
# Actual Value $9,150.80, Predicted value $8,937.75 (%2.33)
# Actual Value $9,136.40, Predicted value $8,937.75 (%2.17)
# Actual Value $9,342.15, Predicted value $8,937.75 (%4.33)
# Actual Value $9,359.90, Predicted value $8,937.75 (%4.51)
# Actual Value $9,422.40, Predicted value $8,937.75 (%5.14)
# Actual Value $9,429.45, Predicted value $8,937.75 (%5.21)
# Actual Value $9,509.75, Predicted value $8,937.75 (%6.01)
# Actual Value $9,616.10, Predicted value $8,937.75 (%7.05)
# Actual Value $9,647.25, Predicted value $8,937.75 (%7.35)
# Actual Value $9,578.05, Predicted value $8,937.75 (%6.69)
# Actual Value $9,630.00, Predicted value $8,937.75 (%7.19)
# Actual Value $9,504.10, Predicted value $8,937.75 (%5.96)
# Actual Value $9,674.55, Predicted value $8,937.75 (%7.62)
# Actual Value $9,891.70, Predicted value $8,937.75 (%9.64)
# Actual Value $9,873.30, Predicted value $8,937.75 (%9.48)
# Actual Value $10,020.55, Predicted value $8,937.75 (%10.81)
# Actual Value $10,013.65, Predicted value $8,937.75 (%10.74)
# Actual Value $9,820.25, Predicted value $8,937.75 (%8.99)
# Actual Value $9,904.15, Predicted value $8,937.75 (%9.76)
# Actual Value $9,857.05, Predicted value $8,937.75 (%9.33)
# Actual Value $9,917.90, Predicted value $8,937.75 (%9.88)
# Actual Value $9,929.90, Predicted value $8,937.75 (%9.99)
# Actual Value $10,086.60, Predicted value $8,937.75 (%11.39)
# Actual Value $10,121.90, Predicted value $8,937.75 (%11.70)
# Actual Value $9,768.95, Predicted value $8,937.75 (%8.51)
# Actual Value $9,888.70, Predicted value $8,937.75 (%9.62)
# Actual Value $10,096.40, Predicted value $8,937.75 (%11.48)
# Actual Value $10,146.55, Predicted value $8,937.75 (%11.91)
# Actual Value $10,343.80, Predicted value $8,937.75 (%13.59)
# Actual Value $10,423.80, Predicted value $8,937.75 (%14.26)
# Actual Value $10,308.95, Predicted value $8,937.75 (%13.30)
# Actual Value $10,214.75, Predicted value $8,937.75 (%12.50)
# Actual Value $10,348.75, Predicted value $8,937.75 (%13.63)
# Actual Value $10,226.55, Predicted value $8,937.75 (%12.60)
# Actual Value $10,166.70, Predicted value $8,937.75 (%12.09)
# Actual Value $10,252.10, Predicted value $8,937.75 (%12.82)
# Actual Value $10,440.30, Predicted value $8,937.75 (%14.39)
# Actual Value $10,477.90, Predicted value $8,937.75 (%14.70)
# Actual Value $10,504.80, Predicted value $8,937.75 (%14.92)
# Actual Value $10,651.20, Predicted value $8,937.75 (%16.09)
# Actual Value $10,817.00, Predicted value $8,937.75 (%17.37)
# Actual Value $11,069.65, Predicted value $8,937.75 (%19.26)
# Actual Value $11,016.90, Predicted value $8,937.75 (%18.87)
# Actual Value $10,576.85, Predicted value $8,937.75 (%15.50)
# Actual Value $10,545.50, Predicted value $8,937.75 (%15.25)
# Actual Value $10,382.70, Predicted value $8,937.75 (%13.92)
# Actual Value $10,458.35, Predicted value $8,937.75 (%14.54)
# Actual Value $10,242.65, Predicted value $8,937.75 (%12.74)
# Actual Value $10,360.15, Predicted value $8,937.75 (%13.73)
# Actual Value $10,114.75, Predicted value $8,937.75 (%11.64)
# Actual Value $10,113.70, Predicted value $8,937.75 (%11.63)
# Actual Value $10,325.15, Predicted value $8,937.75 (%13.44)
# Actual Value $10,458.65, Predicted value $8,937.75 (%14.54)
# Actual Value $10,565.30, Predicted value $8,937.75 (%15.40)
# Actual Value $10,617.80, Predicted value $8,937.75 (%15.82)
# Actual Value $10,679.65, Predicted value $8,937.75 (%16.31)
# Actual Value $10,716.55, Predicted value $8,937.75 (%16.60)
# Actual Value $10,682.70, Predicted value $8,937.75 (%16.33)
# Actual Value $10,513.85, Predicted value $8,937.75 (%14.99)
# Actual Value $10,736.15, Predicted value $8,937.75 (%16.75)
# Actual Value $10,768.35, Predicted value $8,937.75 (%17.00)
# Actual Value $10,808.05, Predicted value $8,937.75 (%17.30)
# Actual Value $10,741.10, Predicted value $8,937.75 (%16.79)
# Actual Value $10,589.10, Predicted value $8,937.75 (%15.59)
# Actual Value $10,749.75, Predicted value $8,937.75 (%16.86)
# Actual Value $11,023.20, Predicted value $8,937.75 (%18.92)
# Actual Value $10,957.10, Predicted value $8,937.75 (%18.43)
# Actual Value $11,167.30, Predicted value $8,937.75 (%19.96)
# Actual Value $11,244.70, Predicted value $8,937.75 (%20.52)
# Actual Value $11,470.70, Predicted value $8,937.75 (%22.08)
# Actual Value $11,385.05, Predicted value $8,937.75 (%21.50)
# Actual Value $11,582.75, Predicted value $8,937.75 (%22.84)
# Actual Value $11,676.80, Predicted value $8,937.75 (%23.46)
# Actual Value $11,536.90, Predicted value $8,937.75 (%22.53)
# Actual Value $11,369.90, Predicted value $8,937.75 (%21.39)
# Actual Value $11,234.35, Predicted value $8,937.75 (%20.44)
# Actual Value $10,977.55, Predicted value $8,937.75 (%18.58)
# Actual Value $10,599.25, Predicted value $8,937.75 (%15.68)
# Actual Value $10,234.65, Predicted value $8,937.75 (%12.67)
# Actual Value $10,453.05, Predicted value $8,937.75 (%14.50)
# Actual Value $10,124.90, Predicted value $8,937.75 (%11.73)
# Actual Value $10,380.45, Predicted value $8,937.75 (%13.90)
# Actual Value $10,598.40, Predicted value $8,937.75 (%15.67)
# Actual Value $10,616.70, Predicted value $8,937.75 (%15.81)
# Actual Value $10,526.75, Predicted value $8,937.75 (%15.09)
# Actual Value $10,858.70, Predicted value $8,937.75 (%17.69)
# Actual Value $10,601.15, Predicted value $8,937.75 (%15.69)
# Actual Value $10,791.55, Predicted value $8,937.75 (%17.18)
# Actual Value $10,951.70, Predicted value $8,937.75 (%18.39)
# Actual Value $10,779.80, Predicted value $8,937.75 (%17.09)
# Actual Value $10,672.25, Predicted value $8,937.75 (%16.25)
# Actual Value $10,821.60, Predicted value $8,937.75 (%17.41)
# Actual Value $10,905.20, Predicted value $8,937.75 (%18.04)
# Actual Value $10,849.80, Predicted value $8,937.75 (%17.62)
# Actual Value $10,830.95, Predicted value $8,937.75 (%17.48)
# Actual Value $11,069.40, Predicted value $8,937.75 (%19.26)
# Actual Value $10,746.05, Predicted value $8,937.75 (%16.83)
# Actual Value $10,789.85, Predicted value $8,937.75 (%17.17)
# Actual Value $10,792.50, Predicted value $8,937.75 (%17.19)
# Actual Value $11,058.20, Predicted value $8,937.75 (%19.18)
# Actual Value $11,343.25, Predicted value $8,937.75 (%21.21)
# Actual Value $11,521.05, Predicted value $8,937.75 (%22.42)
# Actual Value $11,570.00, Predicted value $8,937.75 (%22.75)
# Actual Value $11,598.00, Predicted value $8,937.75 (%22.94)
# Actual Value $11,596.70, Predicted value $8,937.75 (%22.93)
# Actual Value $11,752.80, Predicted value $8,937.75 (%23.95)
# Actual Value $11,641.80, Predicted value $8,937.75 (%23.23)
# Actual Value $11,724.75, Predicted value $8,937.75 (%23.77)
# Actual Value $11,301.80, Predicted value $8,937.75 (%20.92)
# Actual Value $11,257.10, Predicted value $8,937.75 (%20.60)
# Actual Value $11,657.05, Predicted value $8,937.75 (%23.33)
# Actual Value $11,945.90, Predicted value $8,937.75 (%25.18)
# Actual Value $11,843.75, Predicted value $8,937.75 (%24.54)
# Actual Value $11,914.05, Predicted value $8,937.75 (%24.98)
# Actual Value $11,831.75, Predicted value $8,937.75 (%24.46)
# Actual Value $11,841.55, Predicted value $8,937.75 (%24.52)
# Actual Value $11,946.75, Predicted value $8,937.75 (%25.19)
# Actual Value $11,582.90, Predicted value $8,937.75 (%22.84)
# Actual Value $11,596.90, Predicted value $8,937.75 (%22.93)
# Actual Value $11,252.15, Predicted value $8,937.75 (%20.57)
# Actual Value $10,980.00, Predicted value $8,937.75 (%18.60)
# Actual Value $11,032.45, Predicted value $8,937.75 (%18.99)
# Actual Value $11,029.40, Predicted value $8,937.75 (%18.96)
# Actual Value $10,741.35, Predicted value $8,937.75 (%16.79)
# Actual Value $10,948.30, Predicted value $8,937.75 (%18.36)
# Actual Value $10,847.90, Predicted value $8,937.75 (%17.61)
# Actual Value $10,982.80, Predicted value $8,937.75 (%18.62)
# Actual Value $10,704.80, Predicted value $8,937.75 (%16.51)
# Actual Value $11,571.20, Predicted value $8,937.75 (%22.76)
# Actual Value $11,314.00, Predicted value $8,937.75 (%21.00)
# Actual Value $11,234.55, Predicted value $8,937.75 (%20.44)
# Actual Value $11,586.35, Predicted value $8,937.75 (%22.86)
# Actual Value $11,582.60, Predicted value $8,937.75 (%22.83)
# Actual Value $11,877.45, Predicted value $8,937.75 (%24.75)
# Actual Value $12,012.05, Predicted value $8,937.75 (%25.59)
# Actual Value $11,872.10, Predicted value $8,937.75 (%24.72)
# Actual Value $11,968.40, Predicted value $8,937.75 (%25.32)
# Actual Value $12,151.15, Predicted value $8,937.75 (%26.45)
# Actual Value $12,018.40, Predicted value $8,937.75 (%25.63)
# Actual Value $11,971.80, Predicted value $8,937.75 (%25.34)
# Actual Value $12,259.70, Predicted value $8,937.75 (%27.10)
# Actual Value $12,126.55, Predicted value $8,937.75 (%26.30)
# Actual Value $12,282.20, Predicted value $8,937.75 (%27.23)
# Actual Value $12,215.90, Predicted value $8,937.75 (%26.84)
# Actual Value $12,355.50, Predicted value $8,937.75 (%27.66)
# Actual Value $12,180.35, Predicted value $8,937.75 (%26.62)
# Actual Value $12,035.80, Predicted value $8,937.75 (%25.74)
# Actual Value $12,137.95, Predicted value $8,937.75 (%26.37)
# Actual Value $12,174.65, Predicted value $8,937.75 (%26.59)
# Actual Value $12,080.85, Predicted value $8,937.75 (%26.02)
# Actual Value $11,633.30, Predicted value $8,937.75 (%23.17)
# Actual Value $11,269.00, Predicted value $8,937.75 (%20.69)
# Actual Value $9,590.15, Predicted value $8,937.75 (%6.80)
# Actual Value $8,263.45, Predicted value $8,292.90 (%-0.36)
# Actual Value $8,641.45, Predicted value $8,634.65 (%0.08)
# Actual Value $8,253.80, Predicted value $8,234.60 (%0.23)
# Actual Value $9,111.90, Predicted value $8,937.75 (%1.91)
# Actual Value $8,992.80, Predicted value $8,937.75 (%0.61)
# Actual Value $9,313.90, Predicted value $8,937.75 (%4.04)
# Actual Value $9,859.90, Predicted value $8,937.75 (%9.35)
# Actual Value $9,199.05, Predicted value $8,937.75 (%2.84)
# Actual Value $9,142.75, Predicted value $8,937.75 (%2.24)
# Actual Value $9,106.25, Predicted value $8,937.75 (%1.85)
# Actual Value $9,490.10, Predicted value $8,937.75 (%5.82)
# Actual Value $10,029.10, Predicted value $8,937.75 (%10.88)
# Actual Value $9,902.00, Predicted value $8,937.75 (%9.74)
# Actual Value $10,091.65, Predicted value $8,937.75 (%11.43)
# Actual Value $10,288.90, Predicted value $8,937.75 (%13.13)
# Actual Value $10,551.70, Predicted value $8,937.75 (%15.30)
# Actual Value $10,813.45, Predicted value $8,937.75 (%17.35)
# Actual Value $10,739.95, Predicted value $8,937.75 (%16.78)
# Actual Value $11,215.45, Predicted value $8,937.75 (%20.31)
# Actual Value $11,102.15, Predicted value $8,937.75 (%19.50)
# Actual Value $11,200.15, Predicted value $8,937.75 (%20.20)
# Actual Value $11,300.45, Predicted value $8,937.75 (%20.91)
# Actual Value $11,312.20, Predicted value $8,937.75 (%20.99)
# Actual Value $11,559.25, Predicted value $8,937.75 (%22.68)
# Actual Value $11,527.45, Predicted value $8,937.75 (%22.47)
# Actual Value $11,449.25, Predicted value $8,937.75 (%21.94)
# Actual Value $11,516.10, Predicted value $8,937.75 (%22.39)
# Actual Value $10,805.55, Predicted value $8,937.75 (%17.29)
# Actual Value $11,416.95, Predicted value $8,937.75 (%21.72)
# Actual Value $11,834.60, Predicted value $8,937.75 (%24.48)
# Actual Value $11,680.35, Predicted value $8,937.75 (%23.48)
# Actual Value $11,896.45, Predicted value $8,937.75 (%24.87)
# Actual Value $11,670.80, Predicted value $8,937.75 (%23.42)
# Actual Value $12,120.30, Predicted value $8,937.75 (%26.26)
# Actual Value $12,690.80, Predicted value $8,937.75 (%29.57)
# Actual Value $12,771.70, Predicted value $8,937.75 (%30.02)
# Actual Value $12,987.00, Predicted value $8,937.75 (%31.18)
# Actual Value $13,133.90, Predicted value $8,937.75 (%31.95)
# Actual Value $13,478.30, Predicted value $8,937.75 (%33.69)
# Actual Value $13,740.70, Predicted value $8,937.75 (%34.95)
# Actual Value $13,749.25, Predicted value $8,937.75 (%34.99)
# Actual Value $13,981.75, Predicted value $8,937.75 (%36.08)
# Actual Value $14,146.25, Predicted value $8,937.75 (%36.82)
# Actual Value $14,188.90, Predicted value $8,937.75 (%37.01)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_DTR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_DTR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_DTR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_DTR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_DTR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 1693.35
# Mean squared error = 4232999.99
# Median absolute error = 1741.9
# Explain variance score = 0.14
# R2 score = -1.64

# %%
# Plotting the results

r = range(len(y_pred_DTR))

plt.title("Results Plot of DecisionTreeRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_DTR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using MultiLayeredPerceptronRegressor as model

model_MLP = MLPRegressor(random_state=0, max_iter=100).fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_MLP.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_MLP.score(x_test, y_test))

pickle.dump(model_MLP, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_MLP.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.99259
#
#
# Score on testing data:
# ========================================
# 0.97486
# C:\Users\amolk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
y_pred_MLP = model_MLP.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_MLP)):
    expl=((actual_data[i]-y_pred_MLP[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_MLP[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,492.89 (%2.08)
# Actual Value $8,592.20, Predicted value $8,460.19 (%1.54)
# Actual Value $8,774.65, Predicted value $8,581.50 (%2.20)
# Actual Value $8,952.50, Predicted value $8,743.17 (%2.34)
# Actual Value $8,742.55, Predicted value $8,655.14 (%1.00)
# Actual Value $8,867.45, Predicted value $8,672.60 (%2.20)
# Actual Value $8,591.25, Predicted value $8,558.51 (%0.38)
# Actual Value $8,709.55, Predicted value $8,532.14 (%2.04)
# Actual Value $8,573.35, Predicted value $8,503.14 (%0.82)
# Actual Value $8,699.40, Predicted value $8,511.30 (%2.16)
# Actual Value $8,615.25, Predicted value $8,490.65 (%1.45)
# Actual Value $8,484.95, Predicted value $8,384.47 (%1.18)
# Actual Value $8,525.75, Predicted value $8,402.35 (%1.45)
# Actual Value $8,079.95, Predicted value $8,102.45 (%-0.28)
# Actual Value $7,965.50, Predicted value $7,875.48 (%1.13)
# Actual Value $8,192.90, Predicted value $8,009.37 (%2.24)
# Actual Value $8,246.85, Predicted value $8,064.54 (%2.21)
# Actual Value $8,153.60, Predicted value $8,040.36 (%1.39)
# Actual Value $7,979.10, Predicted value $7,908.17 (%0.89)
# Actual Value $8,103.60, Predicted value $7,916.46 (%2.31)
# Actual Value $8,273.80, Predicted value $8,074.00 (%2.41)
# Actual Value $8,407.20, Predicted value $8,213.52 (%2.30)
# Actual Value $8,435.10, Predicted value $8,269.19 (%1.97)
# Actual Value $8,602.75, Predicted value $8,397.20 (%2.39)
# Actual Value $8,734.25, Predicted value $8,547.59 (%2.14)
# Actual Value $8,778.40, Predicted value $8,597.89 (%2.06)
# Actual Value $8,778.00, Predicted value $8,616.17 (%1.84)
# Actual Value $8,939.50, Predicted value $8,759.93 (%2.01)
# Actual Value $8,899.75, Predicted value $8,746.17 (%1.73)
# Actual Value $8,927.00, Predicted value $8,743.94 (%2.05)
# Actual Value $9,153.70, Predicted value $8,931.82 (%2.42)
# Actual Value $9,086.30, Predicted value $8,963.46 (%1.35)
# Actual Value $9,173.75, Predicted value $8,976.39 (%2.15)
# Actual Value $9,261.95, Predicted value $9,048.53 (%2.30)
# Actual Value $9,150.80, Predicted value $8,997.41 (%1.68)
# Actual Value $9,136.40, Predicted value $8,975.61 (%1.76)
# Actual Value $9,342.15, Predicted value $9,130.53 (%2.27)
# Actual Value $9,359.90, Predicted value $9,160.17 (%2.13)
# Actual Value $9,422.40, Predicted value $9,227.17 (%2.07)
# Actual Value $9,429.45, Predicted value $9,260.21 (%1.79)
# Actual Value $9,509.75, Predicted value $9,314.41 (%2.05)
# Actual Value $9,616.10, Predicted value $9,405.41 (%2.19)
# Actual Value $9,647.25, Predicted value $9,457.73 (%1.96)
# Actual Value $9,578.05, Predicted value $9,412.08 (%1.73)
# Actual Value $9,630.00, Predicted value $9,437.65 (%2.00)
# Actual Value $9,504.10, Predicted value $9,371.75 (%1.39)
# Actual Value $9,674.55, Predicted value $9,445.19 (%2.37)
# Actual Value $9,891.70, Predicted value $9,646.85 (%2.48)
# Actual Value $9,873.30, Predicted value $9,690.66 (%1.85)
# Actual Value $10,020.55, Predicted value $9,818.45 (%2.02)
# Actual Value $10,013.65, Predicted value $9,833.76 (%1.80)
# Actual Value $9,820.25, Predicted value $9,729.46 (%0.92)
# Actual Value $9,904.15, Predicted value $9,675.96 (%2.30)
# Actual Value $9,857.05, Predicted value $9,662.91 (%1.97)
# Actual Value $9,917.90, Predicted value $9,712.27 (%2.07)
# Actual Value $9,929.90, Predicted value $9,737.01 (%1.94)
# Actual Value $10,086.60, Predicted value $9,866.03 (%2.19)
# Actual Value $10,121.90, Predicted value $9,911.89 (%2.07)
# Actual Value $9,768.95, Predicted value $9,732.49 (%0.37)
# Actual Value $9,888.70, Predicted value $9,680.45 (%2.11)
# Actual Value $10,096.40, Predicted value $9,852.02 (%2.42)
# Actual Value $10,146.55, Predicted value $9,953.00 (%1.91)
# Actual Value $10,343.80, Predicted value $10,107.32 (%2.29)
# Actual Value $10,423.80, Predicted value $10,203.56 (%2.11)
# Actual Value $10,308.95, Predicted value $10,176.72 (%1.28)
# Actual Value $10,214.75, Predicted value $10,062.15 (%1.49)
# Actual Value $10,348.75, Predicted value $10,131.88 (%2.10)
# Actual Value $10,226.55, Predicted value $10,089.55 (%1.34)
# Actual Value $10,166.70, Predicted value $10,007.27 (%1.57)
# Actual Value $10,252.10, Predicted value $10,047.53 (%2.00)
# Actual Value $10,440.30, Predicted value $10,237.55 (%1.94)
# Actual Value $10,477.90, Predicted value $10,267.19 (%2.01)
# Actual Value $10,504.80, Predicted value $10,288.67 (%2.06)
# Actual Value $10,651.20, Predicted value $10,407.12 (%2.29)
# Actual Value $10,817.00, Predicted value $10,590.97 (%2.09)
# Actual Value $11,069.65, Predicted value $10,811.99 (%2.33)
# Actual Value $11,016.90, Predicted value $10,847.01 (%1.54)
# Actual Value $10,576.85, Predicted value $10,563.33 (%0.13)
# Actual Value $10,545.50, Predicted value $10,319.00 (%2.15)
# Actual Value $10,382.70, Predicted value $10,278.68 (%1.00)
# Actual Value $10,458.35, Predicted value $10,274.99 (%1.75)
# Actual Value $10,242.65, Predicted value $10,126.31 (%1.14)
# Actual Value $10,360.15, Predicted value $10,161.63 (%1.92)
# Actual Value $10,114.75, Predicted value $10,020.43 (%0.93)
# Actual Value $10,113.70, Predicted value $9,903.18 (%2.08)
# Actual Value $10,325.15, Predicted value $10,080.65 (%2.37)
# Actual Value $10,458.65, Predicted value $10,219.55 (%2.29)
# Actual Value $10,565.30, Predicted value $10,342.99 (%2.10)
# Actual Value $10,617.80, Predicted value $10,390.27 (%2.14)
# Actual Value $10,679.65, Predicted value $10,502.85 (%1.66)
# Actual Value $10,716.55, Predicted value $10,509.55 (%1.93)
# Actual Value $10,682.70, Predicted value $10,536.62 (%1.37)
# Actual Value $10,513.85, Predicted value $10,375.48 (%1.32)
# Actual Value $10,736.15, Predicted value $10,487.67 (%2.31)
# Actual Value $10,768.35, Predicted value $10,559.61 (%1.94)
# Actual Value $10,808.05, Predicted value $10,589.70 (%2.02)
# Actual Value $10,741.10, Predicted value $10,554.06 (%1.74)
# Actual Value $10,589.10, Predicted value $10,469.63 (%1.13)
# Actual Value $10,749.75, Predicted value $10,508.91 (%2.24)
# Actual Value $11,023.20, Predicted value $10,758.70 (%2.40)
# Actual Value $10,957.10, Predicted value $10,776.68 (%1.65)
# Actual Value $11,167.30, Predicted value $10,903.66 (%2.36)
# Actual Value $11,244.70, Predicted value $11,044.83 (%1.78)
# Actual Value $11,470.70, Predicted value $11,204.90 (%2.32)
# Actual Value $11,385.05, Predicted value $11,185.73 (%1.75)
# Actual Value $11,582.75, Predicted value $11,320.34 (%2.27)
# Actual Value $11,676.80, Predicted value $11,435.29 (%2.07)
# Actual Value $11,536.90, Predicted value $11,392.87 (%1.25)
# Actual Value $11,369.90, Predicted value $11,239.68 (%1.15)
# Actual Value $11,234.35, Predicted value $11,121.07 (%1.01)
# Actual Value $10,977.55, Predicted value $10,927.31 (%0.46)
# Actual Value $10,599.25, Predicted value $10,596.03 (%0.03)
# Actual Value $10,234.65, Predicted value $10,179.64 (%0.54)
# Actual Value $10,453.05, Predicted value $10,284.48 (%1.61)
# Actual Value $10,124.90, Predicted value $10,041.30 (%0.83)
# Actual Value $10,380.45, Predicted value $10,152.19 (%2.20)
# Actual Value $10,598.40, Predicted value $10,352.13 (%2.32)
# Actual Value $10,616.70, Predicted value $10,411.82 (%1.93)
# Actual Value $10,526.75, Predicted value $10,400.76 (%1.20)
# Actual Value $10,858.70, Predicted value $10,595.55 (%2.42)
# Actual Value $10,601.15, Predicted value $10,541.97 (%0.56)
# Actual Value $10,791.55, Predicted value $10,582.70 (%1.94)
# Actual Value $10,951.70, Predicted value $10,706.92 (%2.24)
# Actual Value $10,779.80, Predicted value $10,657.93 (%1.13)
# Actual Value $10,672.25, Predicted value $10,546.80 (%1.18)
# Actual Value $10,821.60, Predicted value $10,592.66 (%2.12)
# Actual Value $10,905.20, Predicted value $10,680.75 (%2.06)
# Actual Value $10,849.80, Predicted value $10,677.35 (%1.59)
# Actual Value $10,830.95, Predicted value $10,662.37 (%1.56)
# Actual Value $11,069.40, Predicted value $10,820.18 (%2.25)
# Actual Value $10,746.05, Predicted value $10,669.48 (%0.71)
# Actual Value $10,789.85, Predicted value $10,581.92 (%1.93)
# Actual Value $10,792.50, Predicted value $10,614.15 (%1.65)
# Actual Value $11,058.20, Predicted value $10,801.18 (%2.32)
# Actual Value $11,343.25, Predicted value $11,073.47 (%2.38)
# Actual Value $11,521.05, Predicted value $11,264.33 (%2.23)
# Actual Value $11,570.00, Predicted value $11,347.25 (%1.93)
# Actual Value $11,598.00, Predicted value $11,409.40 (%1.63)
# Actual Value $11,596.70, Predicted value $11,394.03 (%1.75)
# Actual Value $11,752.80, Predicted value $11,511.01 (%2.06)
# Actual Value $11,641.80, Predicted value $11,462.14 (%1.54)
# Actual Value $11,724.75, Predicted value $11,486.33 (%2.03)
# Actual Value $11,301.80, Predicted value $11,294.42 (%0.07)
# Actual Value $11,257.10, Predicted value $11,070.65 (%1.66)
# Actual Value $11,657.05, Predicted value $11,467.04 (%1.63)
# Actual Value $11,945.90, Predicted value $11,680.47 (%2.22)
# Actual Value $11,843.75, Predicted value $11,700.03 (%1.21)
# Actual Value $11,914.05, Predicted value $11,685.80 (%1.92)
# Actual Value $11,831.75, Predicted value $11,639.64 (%1.62)
# Actual Value $11,841.55, Predicted value $11,623.42 (%1.84)
# Actual Value $11,946.75, Predicted value $11,692.99 (%2.12)
# Actual Value $11,582.90, Predicted value $11,550.13 (%0.28)
# Actual Value $11,596.90, Predicted value $11,392.49 (%1.76)
# Actual Value $11,252.15, Predicted value $11,217.04 (%0.31)
# Actual Value $10,980.00, Predicted value $10,917.79 (%0.57)
# Actual Value $11,032.45, Predicted value $10,818.13 (%1.94)
# Actual Value $11,029.40, Predicted value $10,862.69 (%1.51)
# Actual Value $10,741.35, Predicted value $10,707.40 (%0.32)
# Actual Value $10,948.30, Predicted value $10,755.37 (%1.76)
# Actual Value $10,847.90, Predicted value $10,718.53 (%1.19)
# Actual Value $10,982.80, Predicted value $10,769.90 (%1.94)
# Actual Value $10,704.80, Predicted value $10,662.39 (%0.40)
# Actual Value $11,571.20, Predicted value $11,271.50 (%2.59)
# Actual Value $11,314.00, Predicted value $11,232.23 (%0.72)
# Actual Value $11,234.55, Predicted value $11,101.60 (%1.18)
# Actual Value $11,586.35, Predicted value $11,315.92 (%2.33)
# Actual Value $11,582.60, Predicted value $11,390.27 (%1.66)
# Actual Value $11,877.45, Predicted value $11,643.66 (%1.97)
# Actual Value $12,012.05, Predicted value $11,760.77 (%2.09)
# Actual Value $11,872.10, Predicted value $11,705.19 (%1.41)
# Actual Value $11,968.40, Predicted value $11,738.61 (%1.92)
# Actual Value $12,151.15, Predicted value $11,890.72 (%2.14)
# Actual Value $12,018.40, Predicted value $11,850.74 (%1.40)
# Actual Value $11,971.80, Predicted value $11,787.06 (%1.54)
# Actual Value $12,259.70, Predicted value $11,976.63 (%2.31)
# Actual Value $12,126.55, Predicted value $11,954.61 (%1.42)
# Actual Value $12,282.20, Predicted value $12,010.85 (%2.21)
# Actual Value $12,215.90, Predicted value $12,007.79 (%1.70)
# Actual Value $12,355.50, Predicted value $12,104.81 (%2.03)
# Actual Value $12,180.35, Predicted value $12,038.66 (%1.16)
# Actual Value $12,035.80, Predicted value $11,888.23 (%1.23)
# Actual Value $12,137.95, Predicted value $11,934.80 (%1.67)
# Actual Value $12,174.65, Predicted value $11,947.61 (%1.86)
# Actual Value $12,080.85, Predicted value $11,915.23 (%1.37)
# Actual Value $11,633.30, Predicted value $11,591.48 (%0.36)
# Actual Value $11,269.00, Predicted value $11,145.23 (%1.10)
# Actual Value $9,590.15, Predicted value $10,150.90 (%-5.85)
# Actual Value $8,263.45, Predicted value $8,894.76 (%-7.64)
# Actual Value $8,641.45, Predicted value $8,564.11 (%0.90)
# Actual Value $8,253.80, Predicted value $8,476.26 (%-2.70)
# Actual Value $9,111.90, Predicted value $8,856.79 (%2.80)
# Actual Value $8,992.80, Predicted value $8,925.78 (%0.75)
# Actual Value $9,313.90, Predicted value $9,192.21 (%1.31)
# Actual Value $9,859.90, Predicted value $9,578.49 (%2.85)
# Actual Value $9,199.05, Predicted value $9,194.66 (%0.05)
# Actual Value $9,142.75, Predicted value $9,155.69 (%-0.14)
# Actual Value $9,106.25, Predicted value $8,994.51 (%1.23)
# Actual Value $9,490.10, Predicted value $9,256.22 (%2.46)
# Actual Value $10,029.10, Predicted value $9,798.81 (%2.30)
# Actual Value $9,902.00, Predicted value $9,881.43 (%0.21)
# Actual Value $10,091.65, Predicted value $9,825.04 (%2.64)
# Actual Value $10,288.90, Predicted value $10,148.86 (%1.36)
# Actual Value $10,551.70, Predicted value $10,341.75 (%1.99)
# Actual Value $10,813.45, Predicted value $10,583.41 (%2.13)
# Actual Value $10,739.95, Predicted value $10,589.48 (%1.40)
# Actual Value $11,215.45, Predicted value $10,933.91 (%2.51)
# Actual Value $11,102.15, Predicted value $10,961.44 (%1.27)
# Actual Value $11,200.15, Predicted value $11,005.02 (%1.74)
# Actual Value $11,300.45, Predicted value $11,078.22 (%1.97)
# Actual Value $11,312.20, Predicted value $11,154.55 (%1.39)
# Actual Value $11,559.25, Predicted value $11,327.42 (%2.01)
# Actual Value $11,527.45, Predicted value $11,414.70 (%0.98)
# Actual Value $11,449.25, Predicted value $11,224.54 (%1.96)
# Actual Value $11,516.10, Predicted value $11,301.08 (%1.87)
# Actual Value $10,805.55, Predicted value $10,991.65 (%-1.72)
# Actual Value $11,416.95, Predicted value $11,117.10 (%2.63)
# Actual Value $11,834.60, Predicted value $11,561.17 (%2.31)
# Actual Value $11,680.35, Predicted value $11,580.64 (%0.85)
# Actual Value $11,896.45, Predicted value $11,668.23 (%1.92)
# Actual Value $11,670.80, Predicted value $11,590.23 (%0.69)
# Actual Value $12,120.30, Predicted value $11,826.32 (%2.43)
# Actual Value $12,690.80, Predicted value $12,384.08 (%2.42)
# Actual Value $12,771.70, Predicted value $12,551.05 (%1.73)
# Actual Value $12,987.00, Predicted value $12,749.34 (%1.83)
# Actual Value $13,133.90, Predicted value $12,880.49 (%1.93)
# Actual Value $13,478.30, Predicted value $13,178.92 (%2.22)
# Actual Value $13,740.70, Predicted value $13,440.81 (%2.18)
# Actual Value $13,749.25, Predicted value $13,526.37 (%1.62)
# Actual Value $13,981.75, Predicted value $13,670.20 (%2.23)
# Actual Value $14,146.25, Predicted value $13,875.94 (%1.91)
# Actual Value $14,188.90, Predicted value $14,251.23 (%-0.44)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_MLP), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_MLP), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_MLP), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_MLP), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_MLP), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 184.94
# Mean squared error = 40303.17
# Median absolute error = 194.14
# Explain variance score = 0.99
# R2 score = 0.97

# %%
# Plotting the results

r = range(len(y_pred_DTR))

plt.title("Results Plot of MultiLayeredPerceptronRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_MLP, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()

# %%
# Training our dataset using VotingRegressor as model

model_VR = VotingRegressor(estimators=[('ml', model_LR), ('msv', model_SVR)])
model_VR.fit(x_train, y_train)

print("\n\nScore on training data:")
print("========================================")
print("%.5f" %model_VR.score(x_train, y_train))

print("\n\nScore on testing data:")
print("========================================")
print("%.5f" %model_VR.score(x_test, y_test))

pickle.dump(model_VR, open('D:\\Stock\\stockClosingPricePrediction-app-main\\models\\model_VR.pkl', 'wb'))
# Out:
# Score on training data:
# ========================================
# 0.75489
#
#
# Score on testing data:
# ========================================
# -2.44833

# %%
y_pred_VR = model_MLP.predict(x_test)
actual_data = np.array(y_test)

print("\n\nDifference between Actual value and Predicted value:")
print("========================================")

for i in range(len(y_pred_VR)):
    expl=((actual_data[i]-y_pred_VR[i])/actual_data[i])*100.0
    print('Actual Value ${:,.2f}, Predicted value ${:,.2f} (%{:,.2f})'.format(actual_data[i], y_pred_VR[i], expl))
# Out:
# Difference between Actual value and Predicted value:
# ========================================
# Actual Value $8,673.25, Predicted value $8,492.89 (%2.08)
# Actual Value $8,592.20, Predicted value $8,460.19 (%1.54)
# Actual Value $8,774.65, Predicted value $8,581.50 (%2.20)
# Actual Value $8,952.50, Predicted value $8,743.17 (%2.34)
# Actual Value $8,742.55, Predicted value $8,655.14 (%1.00)
# Actual Value $8,867.45, Predicted value $8,672.60 (%2.20)
# Actual Value $8,591.25, Predicted value $8,558.51 (%0.38)
# Actual Value $8,709.55, Predicted value $8,532.14 (%2.04)
# Actual Value $8,573.35, Predicted value $8,503.14 (%0.82)
# Actual Value $8,699.40, Predicted value $8,511.30 (%2.16)
# Actual Value $8,615.25, Predicted value $8,490.65 (%1.45)
# Actual Value $8,484.95, Predicted value $8,384.47 (%1.18)
# Actual Value $8,525.75, Predicted value $8,402.35 (%1.45)
# Actual Value $8,079.95, Predicted value $8,102.45 (%-0.28)
# Actual Value $7,965.50, Predicted value $7,875.48 (%1.13)
# Actual Value $8,192.90, Predicted value $8,009.37 (%2.24)
# Actual Value $8,246.85, Predicted value $8,064.54 (%2.21)
# Actual Value $8,153.60, Predicted value $8,040.36 (%1.39)
# Actual Value $7,979.10, Predicted value $7,908.17 (%0.89)
# Actual Value $8,103.60, Predicted value $7,916.46 (%2.31)
# Actual Value $8,273.80, Predicted value $8,074.00 (%2.41)
# Actual Value $8,407.20, Predicted value $8,213.52 (%2.30)
# Actual Value $8,435.10, Predicted value $8,269.19 (%1.97)
# Actual Value $8,602.75, Predicted value $8,397.20 (%2.39)
# Actual Value $8,734.25, Predicted value $8,547.59 (%2.14)
# Actual Value $8,778.40, Predicted value $8,597.89 (%2.06)
# Actual Value $8,778.00, Predicted value $8,616.17 (%1.84)
# Actual Value $8,939.50, Predicted value $8,759.93 (%2.01)
# Actual Value $8,899.75, Predicted value $8,746.17 (%1.73)
# Actual Value $8,927.00, Predicted value $8,743.94 (%2.05)
# Actual Value $9,153.70, Predicted value $8,931.82 (%2.42)
# Actual Value $9,086.30, Predicted value $8,963.46 (%1.35)
# Actual Value $9,173.75, Predicted value $8,976.39 (%2.15)
# Actual Value $9,261.95, Predicted value $9,048.53 (%2.30)
# Actual Value $9,150.80, Predicted value $8,997.41 (%1.68)
# Actual Value $9,136.40, Predicted value $8,975.61 (%1.76)
# Actual Value $9,342.15, Predicted value $9,130.53 (%2.27)
# Actual Value $9,359.90, Predicted value $9,160.17 (%2.13)
# Actual Value $9,422.40, Predicted value $9,227.17 (%2.07)
# Actual Value $9,429.45, Predicted value $9,260.21 (%1.79)
# Actual Value $9,509.75, Predicted value $9,314.41 (%2.05)
# Actual Value $9,616.10, Predicted value $9,405.41 (%2.19)
# Actual Value $9,647.25, Predicted value $9,457.73 (%1.96)
# Actual Value $9,578.05, Predicted value $9,412.08 (%1.73)
# Actual Value $9,630.00, Predicted value $9,437.65 (%2.00)
# Actual Value $9,504.10, Predicted value $9,371.75 (%1.39)
# Actual Value $9,674.55, Predicted value $9,445.19 (%2.37)
# Actual Value $9,891.70, Predicted value $9,646.85 (%2.48)
# Actual Value $9,873.30, Predicted value $9,690.66 (%1.85)
# Actual Value $10,020.55, Predicted value $9,818.45 (%2.02)
# Actual Value $10,013.65, Predicted value $9,833.76 (%1.80)
# Actual Value $9,820.25, Predicted value $9,729.46 (%0.92)
# Actual Value $9,904.15, Predicted value $9,675.96 (%2.30)
# Actual Value $9,857.05, Predicted value $9,662.91 (%1.97)
# Actual Value $9,917.90, Predicted value $9,712.27 (%2.07)
# Actual Value $9,929.90, Predicted value $9,737.01 (%1.94)
# Actual Value $10,086.60, Predicted value $9,866.03 (%2.19)
# Actual Value $10,121.90, Predicted value $9,911.89 (%2.07)
# Actual Value $9,768.95, Predicted value $9,732.49 (%0.37)
# Actual Value $9,888.70, Predicted value $9,680.45 (%2.11)
# Actual Value $10,096.40, Predicted value $9,852.02 (%2.42)
# Actual Value $10,146.55, Predicted value $9,953.00 (%1.91)
# Actual Value $10,343.80, Predicted value $10,107.32 (%2.29)
# Actual Value $10,423.80, Predicted value $10,203.56 (%2.11)
# Actual Value $10,308.95, Predicted value $10,176.72 (%1.28)
# Actual Value $10,214.75, Predicted value $10,062.15 (%1.49)
# Actual Value $10,348.75, Predicted value $10,131.88 (%2.10)
# Actual Value $10,226.55, Predicted value $10,089.55 (%1.34)
# Actual Value $10,166.70, Predicted value $10,007.27 (%1.57)
# Actual Value $10,252.10, Predicted value $10,047.53 (%2.00)
# Actual Value $10,440.30, Predicted value $10,237.55 (%1.94)
# Actual Value $10,477.90, Predicted value $10,267.19 (%2.01)
# Actual Value $10,504.80, Predicted value $10,288.67 (%2.06)
# Actual Value $10,651.20, Predicted value $10,407.12 (%2.29)
# Actual Value $10,817.00, Predicted value $10,590.97 (%2.09)
# Actual Value $11,069.65, Predicted value $10,811.99 (%2.33)
# Actual Value $11,016.90, Predicted value $10,847.01 (%1.54)
# Actual Value $10,576.85, Predicted value $10,563.33 (%0.13)
# Actual Value $10,545.50, Predicted value $10,319.00 (%2.15)
# Actual Value $10,382.70, Predicted value $10,278.68 (%1.00)
# Actual Value $10,458.35, Predicted value $10,274.99 (%1.75)
# Actual Value $10,242.65, Predicted value $10,126.31 (%1.14)
# Actual Value $10,360.15, Predicted value $10,161.63 (%1.92)
# Actual Value $10,114.75, Predicted value $10,020.43 (%0.93)
# Actual Value $10,113.70, Predicted value $9,903.18 (%2.08)
# Actual Value $10,325.15, Predicted value $10,080.65 (%2.37)
# Actual Value $10,458.65, Predicted value $10,219.55 (%2.29)
# Actual Value $10,565.30, Predicted value $10,342.99 (%2.10)
# Actual Value $10,617.80, Predicted value $10,390.27 (%2.14)
# Actual Value $10,679.65, Predicted value $10,502.85 (%1.66)
# Actual Value $10,716.55, Predicted value $10,509.55 (%1.93)
# Actual Value $10,682.70, Predicted value $10,536.62 (%1.37)
# Actual Value $10,513.85, Predicted value $10,375.48 (%1.32)
# Actual Value $10,736.15, Predicted value $10,487.67 (%2.31)
# Actual Value $10,768.35, Predicted value $10,559.61 (%1.94)
# Actual Value $10,808.05, Predicted value $10,589.70 (%2.02)
# Actual Value $10,741.10, Predicted value $10,554.06 (%1.74)
# Actual Value $10,589.10, Predicted value $10,469.63 (%1.13)
# Actual Value $10,749.75, Predicted value $10,508.91 (%2.24)
# Actual Value $11,023.20, Predicted value $10,758.70 (%2.40)
# Actual Value $10,957.10, Predicted value $10,776.68 (%1.65)
# Actual Value $11,167.30, Predicted value $10,903.66 (%2.36)
# Actual Value $11,244.70, Predicted value $11,044.83 (%1.78)
# Actual Value $11,470.70, Predicted value $11,204.90 (%2.32)
# Actual Value $11,385.05, Predicted value $11,185.73 (%1.75)
# Actual Value $11,582.75, Predicted value $11,320.34 (%2.27)
# Actual Value $11,676.80, Predicted value $11,435.29 (%2.07)
# Actual Value $11,536.90, Predicted value $11,392.87 (%1.25)
# Actual Value $11,369.90, Predicted value $11,239.68 (%1.15)
# Actual Value $11,234.35, Predicted value $11,121.07 (%1.01)
# Actual Value $10,977.55, Predicted value $10,927.31 (%0.46)
# Actual Value $10,599.25, Predicted value $10,596.03 (%0.03)
# Actual Value $10,234.65, Predicted value $10,179.64 (%0.54)
# Actual Value $10,453.05, Predicted value $10,284.48 (%1.61)
# Actual Value $10,124.90, Predicted value $10,041.30 (%0.83)
# Actual Value $10,380.45, Predicted value $10,152.19 (%2.20)
# Actual Value $10,598.40, Predicted value $10,352.13 (%2.32)
# Actual Value $10,616.70, Predicted value $10,411.82 (%1.93)
# Actual Value $10,526.75, Predicted value $10,400.76 (%1.20)
# Actual Value $10,858.70, Predicted value $10,595.55 (%2.42)
# Actual Value $10,601.15, Predicted value $10,541.97 (%0.56)
# Actual Value $10,791.55, Predicted value $10,582.70 (%1.94)
# Actual Value $10,951.70, Predicted value $10,706.92 (%2.24)
# Actual Value $10,779.80, Predicted value $10,657.93 (%1.13)
# Actual Value $10,672.25, Predicted value $10,546.80 (%1.18)
# Actual Value $10,821.60, Predicted value $10,592.66 (%2.12)
# Actual Value $10,905.20, Predicted value $10,680.75 (%2.06)
# Actual Value $10,849.80, Predicted value $10,677.35 (%1.59)
# Actual Value $10,830.95, Predicted value $10,662.37 (%1.56)
# Actual Value $11,069.40, Predicted value $10,820.18 (%2.25)
# Actual Value $10,746.05, Predicted value $10,669.48 (%0.71)
# Actual Value $10,789.85, Predicted value $10,581.92 (%1.93)
# Actual Value $10,792.50, Predicted value $10,614.15 (%1.65)
# Actual Value $11,058.20, Predicted value $10,801.18 (%2.32)
# Actual Value $11,343.25, Predicted value $11,073.47 (%2.38)
# Actual Value $11,521.05, Predicted value $11,264.33 (%2.23)
# Actual Value $11,570.00, Predicted value $11,347.25 (%1.93)
# Actual Value $11,598.00, Predicted value $11,409.40 (%1.63)
# Actual Value $11,596.70, Predicted value $11,394.03 (%1.75)
# Actual Value $11,752.80, Predicted value $11,511.01 (%2.06)
# Actual Value $11,641.80, Predicted value $11,462.14 (%1.54)
# Actual Value $11,724.75, Predicted value $11,486.33 (%2.03)
# Actual Value $11,301.80, Predicted value $11,294.42 (%0.07)
# Actual Value $11,257.10, Predicted value $11,070.65 (%1.66)
# Actual Value $11,657.05, Predicted value $11,467.04 (%1.63)
# Actual Value $11,945.90, Predicted value $11,680.47 (%2.22)
# Actual Value $11,843.75, Predicted value $11,700.03 (%1.21)
# Actual Value $11,914.05, Predicted value $11,685.80 (%1.92)
# Actual Value $11,831.75, Predicted value $11,639.64 (%1.62)
# Actual Value $11,841.55, Predicted value $11,623.42 (%1.84)
# Actual Value $11,946.75, Predicted value $11,692.99 (%2.12)
# Actual Value $11,582.90, Predicted value $11,550.13 (%0.28)
# Actual Value $11,596.90, Predicted value $11,392.49 (%1.76)
# Actual Value $11,252.15, Predicted value $11,217.04 (%0.31)
# Actual Value $10,980.00, Predicted value $10,917.79 (%0.57)
# Actual Value $11,032.45, Predicted value $10,818.13 (%1.94)
# Actual Value $11,029.40, Predicted value $10,862.69 (%1.51)
# Actual Value $10,741.35, Predicted value $10,707.40 (%0.32)
# Actual Value $10,948.30, Predicted value $10,755.37 (%1.76)
# Actual Value $10,847.90, Predicted value $10,718.53 (%1.19)
# Actual Value $10,982.80, Predicted value $10,769.90 (%1.94)
# Actual Value $10,704.80, Predicted value $10,662.39 (%0.40)
# Actual Value $11,571.20, Predicted value $11,271.50 (%2.59)
# Actual Value $11,314.00, Predicted value $11,232.23 (%0.72)
# Actual Value $11,234.55, Predicted value $11,101.60 (%1.18)
# Actual Value $11,586.35, Predicted value $11,315.92 (%2.33)
# Actual Value $11,582.60, Predicted value $11,390.27 (%1.66)
# Actual Value $11,877.45, Predicted value $11,643.66 (%1.97)
# Actual Value $12,012.05, Predicted value $11,760.77 (%2.09)
# Actual Value $11,872.10, Predicted value $11,705.19 (%1.41)
# Actual Value $11,968.40, Predicted value $11,738.61 (%1.92)
# Actual Value $12,151.15, Predicted value $11,890.72 (%2.14)
# Actual Value $12,018.40, Predicted value $11,850.74 (%1.40)
# Actual Value $11,971.80, Predicted value $11,787.06 (%1.54)
# Actual Value $12,259.70, Predicted value $11,976.63 (%2.31)
# Actual Value $12,126.55, Predicted value $11,954.61 (%1.42)
# Actual Value $12,282.20, Predicted value $12,010.85 (%2.21)
# Actual Value $12,215.90, Predicted value $12,007.79 (%1.70)
# Actual Value $12,355.50, Predicted value $12,104.81 (%2.03)
# Actual Value $12,180.35, Predicted value $12,038.66 (%1.16)
# Actual Value $12,035.80, Predicted value $11,888.23 (%1.23)
# Actual Value $12,137.95, Predicted value $11,934.80 (%1.67)
# Actual Value $12,174.65, Predicted value $11,947.61 (%1.86)
# Actual Value $12,080.85, Predicted value $11,915.23 (%1.37)
# Actual Value $11,633.30, Predicted value $11,591.48 (%0.36)
# Actual Value $11,269.00, Predicted value $11,145.23 (%1.10)
# Actual Value $9,590.15, Predicted value $10,150.90 (%-5.85)
# Actual Value $8,263.45, Predicted value $8,894.76 (%-7.64)
# Actual Value $8,641.45, Predicted value $8,564.11 (%0.90)
# Actual Value $8,253.80, Predicted value $8,476.26 (%-2.70)
# Actual Value $9,111.90, Predicted value $8,856.79 (%2.80)
# Actual Value $8,992.80, Predicted value $8,925.78 (%0.75)
# Actual Value $9,313.90, Predicted value $9,192.21 (%1.31)
# Actual Value $9,859.90, Predicted value $9,578.49 (%2.85)
# Actual Value $9,199.05, Predicted value $9,194.66 (%0.05)
# Actual Value $9,142.75, Predicted value $9,155.69 (%-0.14)
# Actual Value $9,106.25, Predicted value $8,994.51 (%1.23)
# Actual Value $9,490.10, Predicted value $9,256.22 (%2.46)
# Actual Value $10,029.10, Predicted value $9,798.81 (%2.30)
# Actual Value $9,902.00, Predicted value $9,881.43 (%0.21)
# Actual Value $10,091.65, Predicted value $9,825.04 (%2.64)
# Actual Value $10,288.90, Predicted value $10,148.86 (%1.36)
# Actual Value $10,551.70, Predicted value $10,341.75 (%1.99)
# Actual Value $10,813.45, Predicted value $10,583.41 (%2.13)
# Actual Value $10,739.95, Predicted value $10,589.48 (%1.40)
# Actual Value $11,215.45, Predicted value $10,933.91 (%2.51)
# Actual Value $11,102.15, Predicted value $10,961.44 (%1.27)
# Actual Value $11,200.15, Predicted value $11,005.02 (%1.74)
# Actual Value $11,300.45, Predicted value $11,078.22 (%1.97)
# Actual Value $11,312.20, Predicted value $11,154.55 (%1.39)
# Actual Value $11,559.25, Predicted value $11,327.42 (%2.01)
# Actual Value $11,527.45, Predicted value $11,414.70 (%0.98)
# Actual Value $11,449.25, Predicted value $11,224.54 (%1.96)
# Actual Value $11,516.10, Predicted value $11,301.08 (%1.87)
# Actual Value $10,805.55, Predicted value $10,991.65 (%-1.72)
# Actual Value $11,416.95, Predicted value $11,117.10 (%2.63)
# Actual Value $11,834.60, Predicted value $11,561.17 (%2.31)
# Actual Value $11,680.35, Predicted value $11,580.64 (%0.85)
# Actual Value $11,896.45, Predicted value $11,668.23 (%1.92)
# Actual Value $11,670.80, Predicted value $11,590.23 (%0.69)
# Actual Value $12,120.30, Predicted value $11,826.32 (%2.43)
# Actual Value $12,690.80, Predicted value $12,384.08 (%2.42)
# Actual Value $12,771.70, Predicted value $12,551.05 (%1.73)
# Actual Value $12,987.00, Predicted value $12,749.34 (%1.83)
# Actual Value $13,133.90, Predicted value $12,880.49 (%1.93)
# Actual Value $13,478.30, Predicted value $13,178.92 (%2.22)
# Actual Value $13,740.70, Predicted value $13,440.81 (%2.18)
# Actual Value $13,749.25, Predicted value $13,526.37 (%1.62)
# Actual Value $13,981.75, Predicted value $13,670.20 (%2.23)
# Actual Value $14,146.25, Predicted value $13,875.94 (%1.91)
# Actual Value $14,188.90, Predicted value $14,251.23 (%-0.44)

# %%
print("\nEvaluation according to different parameters:")
print("========================================")

print("\nMean absolute error =", round(sm.mean_absolute_error(y_test, y_pred_VR), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred_VR), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_pred_VR), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_pred_VR), 2)) 
print("R2 score =", round(sm.r2_score(y_test, y_pred_VR), 2))
# Out:
# Evaluation according to different parameters:
# ========================================
#
# Mean absolute error = 184.94
# Mean squared error = 40303.17
# Median absolute error = 194.14
# Explain variance score = 0.99
# R2 score = 0.97

# %%
# Plotting the results

r = range(len(y_pred_DTR))

plt.title("Results Plot of VotingRegressor")
plt.plot(r, y_test, color='blue', label='acc')
plt.plot(r, y_pred_VR, color='brown', label='val_acc')
plt.xlabel("Data")
plt.ylabel("Result value")
plt.legend()
